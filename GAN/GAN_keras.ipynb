# %%
from __future__ import print_function

from keras import backend as K
K.set_image_dim_ordering('th') # ensure our dimension notation matches

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Reshape
from keras.layers.core import Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D
from keras.layers.convolutional import Convolution2D, AveragePooling2D
from keras.layers.core import Flatten
from keras.optimizers import SGD, Adam
from keras.datasets import mnist
from keras import utils
import numpy as np
from PIL import Image, ImageOps
import argparse
import math

import os
import os.path

import glob
# Out:
# Using TensorFlow backend.

# %%
def generator_model():
    model = Sequential()
    model.add(Dense(input_dim=100, output_dim=1024))
    model.add(Activation('tanh'))
    model.add(Dense(128*8*8))
    model.add(BatchNormalization())
    model.add(Activation('tanh'))
    model.add(Reshape((128, 8, 8), input_shape=(128*8*8,)))
    model.add(UpSampling2D(size=(4, 4)))
    model.add(Convolution2D(64, 5, 5, border_mode='same'))
    model.add(Activation('tanh'))
    model.add(UpSampling2D(size=(4, 4)))
    model.add(Convolution2D(1, 5, 5, border_mode='same'))
    model.add(Activation('tanh'))
    return model


def discriminator_model():
    model = Sequential()
    model.add(Convolution2D(
                        64, 5, 5,
                        border_mode='same',
                        input_shape=(1, 128, 128)))
    model.add(Activation('tanh'))
    model.add(AveragePooling2D(pool_size=(4, 4)))
    model.add(Convolution2D(128, 5, 5))
    model.add(Activation('tanh'))
    model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(256))
    model.add(Activation('tanh'))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    return model


def generator_containing_discriminator(generator, discriminator):
    model = Sequential()
    model.add(generator)
    discriminator.trainable = False
    model.add(discriminator)
    return model


def combine_images(generated_images):
    num = generated_images.shape[0]
    width = int(math.sqrt(num))
    height = int(math.ceil(float(num)/width))
    shape = generated_images.shape[2:]
    image = np.zeros((height*shape[0], width*shape[1]),
                     dtype=generated_images.dtype)
    for index, img in enumerate(generated_images):
        i = int(index/width)
        j = index % width
        image[i*shape[0]:(i+1)*shape[0], j*shape[1]:(j+1)*shape[1]] = \
            img[0, :, :]
    return image

# %%
model = generator_model()
print(model.summary())
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0708 14:20:25.923263 140450500568896 deprecation_wrapper.py:119] From /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=100, units=1024)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# W0708 14:20:25.998479 140450500568896 deprecation_wrapper.py:119] From /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0708 14:20:26.006158 140450500568896 deprecation_wrapper.py:119] From /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0708 14:20:26.142378 140450500568896 deprecation_wrapper.py:119] From /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0708 14:20:26.182302 140450500568896 deprecation_wrapper.py:119] From /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# W0708 14:20:26.207917 140450500568896 deprecation_wrapper.py:119] From /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              103424
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8192)              8396800
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8192)              32768
# _________________________________________________________________
# activation_2 (Activation)    (None, 8192)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 128, 8, 8)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 128, 32, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 32, 32)        204864
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 32, 32)        0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 64, 128, 128)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 128, 128)       1601
# _________________________________________________________________
# activation_4 (Activation)    (None, 1, 128, 128)       0
# =================================================================
# Total params: 8,739,457
# Trainable params: 8,723,073
# Non-trainable params: 16,384
# _________________________________________________________________
# None
# /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (5, 5), padding="same")`
#   del sys.path[0]

# %%
def load_data(pixels=128, verbose=False):
    print("Loading data")
    X_train = []
    paths = glob.glob(os.path.normpath(os.getcwd() + '/logos/*.jpg'))
    for path in paths:
        if verbose: print(path)
        im = Image.open(path)
        im = ImageOps.fit(im, (pixels, pixels), Image.ANTIALIAS)
        im = ImageOps.grayscale(im)
        #im.show()
        im = np.asarray(im)
        X_train.append(im)
    print("Finished loading data")
    return np.array(X_train)

def train(epochs, BATCH_SIZE, weights=False):
    """
    :param epochs: Train for this many epochs
    :param BATCH_SIZE: Size of minibatch
    :param weights: If True, load weights from file, otherwise train the model from scratch. 
    Use this if you have already saved state of the network and want to train it further.
    """
    X_train = load_data()
    X_train = (X_train.astype(np.float32) - 127.5)/127.5
    X_train = X_train.reshape((X_train.shape[0], 1) + X_train.shape[1:])
    discriminator = discriminator_model()
    generator = generator_model()
    if weights:
        generator.load_weights('goodgenerator.h5')
        discriminator.load_weights('gooddiscriminator.h5')
    discriminator_on_generator = \
        generator_containing_discriminator(generator, discriminator)
    d_optim = SGD(lr=0.0005, momentum=0.9, nesterov=True)
    g_optim = SGD(lr=0.0005, momentum=0.9, nesterov=True)
    generator.compile(loss='binary_crossentropy', optimizer="SGD")
    discriminator_on_generator.compile(
        loss='binary_crossentropy', optimizer=g_optim)
    discriminator.trainable = True
    discriminator.compile(loss='binary_crossentropy', optimizer=d_optim)
    noise = np.zeros((BATCH_SIZE, 100))
    for epoch in range(epochs):
        print("Epoch is", epoch)
        print("Number of batches", int(X_train.shape[0]/BATCH_SIZE))
        for index in range(int(X_train.shape[0]/BATCH_SIZE)):
            for i in range(BATCH_SIZE):
                noise[i, :] = np.random.uniform(-1, 1, 100)
            image_batch = X_train[index*BATCH_SIZE:(index+1)*BATCH_SIZE]
            generated_images = generator.predict(noise, verbose=0)
            #print(generated_images.shape)
            if index % 20 == 0 and epoch % 10 == 0:
                image = combine_images(generated_images)
                image = image*127.5+127.5
                destpath = os.path.normpath(os.getcwd()+ "/logo-generated-images/"+str(epoch)+"_"+str(index)+".png")
                Image.fromarray(image.astype(np.uint8)).save(destpath)
            X = np.concatenate((image_batch, generated_images))
            y = [1] * BATCH_SIZE + [0] * BATCH_SIZE
            d_loss = discriminator.train_on_batch(X, y)
            print("batch %d d_loss : %f" % (index, d_loss))
            for i in range(BATCH_SIZE):
                noise[i, :] = np.random.uniform(-1, 1, 100)
            discriminator.trainable = False
            g_loss = discriminator_on_generator.train_on_batch(
                noise, [1] * BATCH_SIZE)
            discriminator.trainable = True
            print("batch %d g_loss : %f" % (index, g_loss))
            if epoch % 10 == 9:
                generator.save_weights('goodgenerator.h5', True)
                discriminator.save_weights('gooddiscriminator.h5', True)

def clean(image):
    for i in range(1, image.shape[0] - 1):
        for j in range(1, image.shape[1] - 1):
            if image[i][j] + image[i+1][j] + image[i][j+1] + image[i-1][j] + image[i][j-1] > 127 * 5:
                image[i][j] = 255
    return image
def generate(BATCH_SIZE):
    generator = generator_model()
    generator.compile(loss='binary_crossentropy', optimizer="SGD")
    generator.load_weights('goodgenerator.h5')
    noise = np.zeros((BATCH_SIZE, 100))
    a = np.random.uniform(-1, 1, 100)
    b = np.random.uniform(-1, 1, 100)
    grad = (b - a) / BATCH_SIZE
    for i in range(BATCH_SIZE):
        noise[i, :] = np.random.uniform(-1, 1, 100)
    generated_images = generator.predict(noise, verbose=1)
    #image = combine_images(generated_images)
    print(generated_images.shape)
    for image in generated_images:
        image = image[0]
        image = image*127.5+127.5
        Image.fromarray(image.astype(np.uint8)).save("dirty.png")
        Image.fromarray(image.astype(np.uint8)).show()
        clean(image)
        image = Image.fromarray(image.astype(np.uint8))
        image.show()        
        image.save("clean.png")


def get_args():
    parser = argparse.ArgumentParser()
    parser.add_argument("--mode", type=str)
    parser.add_argument("--batch_size", type=int, default=128)
    parser.add_argument("--nice", dest="nice", action="store_true")
    parser.set_defaults(nice=False)
    args = parser.parse_args()
    return args

# %%
train(400, 10, False)
# Out:
# Loading data
# /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), input_shape=(1, 128, 1..., padding="same")`
# W0708 14:20:32.602955 140450500568896 deprecation_wrapper.py:119] From /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
# Finished loading data
# /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (5, 5))`
# /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=100, units=1024)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (5, 5), padding="same")`
#   del sys.path[0]
# W0708 14:20:33.043668 140450500568896 deprecation_wrapper.py:119] From /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0708 14:20:33.076930 140450500568896 deprecation.py:323] From /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch is 0
# Number of batches 3
# batch 0 d_loss : 0.638710
# batch 0 g_loss : 0.691887
# batch 1 d_loss : 0.614472
# batch 1 g_loss : 0.702981
# batch 2 d_loss : 0.560838
# batch 2 g_loss : 0.688898
# Epoch is 1
# Number of batches 3
# batch 0 d_loss : 0.524556
# batch 0 g_loss : 0.690315
# batch 1 d_loss : 0.477461
# batch 1 g_loss : 0.705460
# batch 2 d_loss : 0.472615
# batch 2 g_loss : 0.697294
# Epoch is 2
# Number of batches 3
# batch 0 d_loss : 0.449285
# batch 0 g_loss : 0.689730
# batch 1 d_loss : 0.428052
# batch 1 g_loss : 0.706146
# batch 2 d_loss : 0.397361
# batch 2 g_loss : 0.703768
# Epoch is 3
# Number of batches 3
# batch 0 d_loss : 0.406947
# batch 0 g_loss : 0.685472
# batch 1 d_loss : 0.392263
# batch 1 g_loss : 0.698797
# batch 2 d_loss : 0.365447
# batch 2 g_loss : 0.704384
# Epoch is 4
# Number of batches 3
# batch 0 d_loss : 0.395766
# batch 0 g_loss : 0.695807
# batch 1 d_loss : 0.392417
# batch 1 g_loss : 0.705975
# batch 2 d_loss : 0.400151
# batch 2 g_loss : 0.702498
# Epoch is 5
# Number of batches 3
# batch 0 d_loss : 0.418813
# batch 0 g_loss : 0.661772
# batch 1 d_loss : 0.358929
# batch 1 g_loss : 0.654534
# batch 2 d_loss : 0.401826
# batch 2 g_loss : 0.673098
# Epoch is 6
# Number of batches 3
# batch 0 d_loss : 0.341035
# batch 0 g_loss : 0.622727
# batch 1 d_loss : 0.428534
# batch 1 g_loss : 0.597199
# batch 2 d_loss : 0.458062
# batch 2 g_loss : 0.599754
# Epoch is 7
# Number of batches 3
# batch 0 d_loss : 0.382819
# batch 0 g_loss : 0.620702
# batch 1 d_loss : 0.447034
# batch 1 g_loss : 0.569627
# batch 2 d_loss : 0.381417
# batch 2 g_loss : 0.594500
# Epoch is 8
# Number of batches 3
# batch 0 d_loss : 0.385976
# batch 0 g_loss : 0.588297
# batch 1 d_loss : 0.444127
# batch 1 g_loss : 0.572996
# batch 2 d_loss : 0.445302
# batch 2 g_loss : 0.556497
# Epoch is 9
# Number of batches 3
# batch 0 d_loss : 0.473794
# batch 0 g_loss : 0.547411
# batch 1 d_loss : 0.487404
# batch 1 g_loss : 0.543879
# batch 2 d_loss : 0.483221
# batch 2 g_loss : 0.579102
# Epoch is 10
# Number of batches 3
# batch 0 d_loss : 0.478571
# batch 0 g_loss : 0.597927
# batch 1 d_loss : 0.454727
# batch 1 g_loss : 0.607096
# batch 2 d_loss : 0.426674
# batch 2 g_loss : 0.585967
# Epoch is 11
# Number of batches 3
# batch 0 d_loss : 0.442292
# batch 0 g_loss : 0.604952
# batch 1 d_loss : 0.458464
# batch 1 g_loss : 0.629055
# batch 2 d_loss : 0.409968
# batch 2 g_loss : 0.648134
# Epoch is 12
# Number of batches 3
# batch 0 d_loss : 0.422514
# batch 0 g_loss : 0.674174
# batch 1 d_loss : 0.404224
# batch 1 g_loss : 0.666929
# batch 2 d_loss : 0.421397
# batch 2 g_loss : 0.704933
# Epoch is 13
# Number of batches 3
# batch 0 d_loss : 0.407675
# batch 0 g_loss : 0.752312
# batch 1 d_loss : 0.374675
# batch 1 g_loss : 0.737755
# batch 2 d_loss : 0.402903
# batch 2 g_loss : 0.786829
# Epoch is 14
# Number of batches 3
# batch 0 d_loss : 0.393060
# batch 0 g_loss : 0.801431
# batch 1 d_loss : 0.402045
# batch 1 g_loss : 0.802609
# batch 2 d_loss : 0.382124
# batch 2 g_loss : 0.818132
# Epoch is 15
# Number of batches 3
# batch 0 d_loss : 0.377953
# batch 0 g_loss : 0.842857
# batch 1 d_loss : 0.395269
# batch 1 g_loss : 0.866363
# batch 2 d_loss : 0.384030
# batch 2 g_loss : 0.895137
# Epoch is 16
# Number of batches 3
# batch 0 d_loss : 0.381973
# batch 0 g_loss : 0.898199
# batch 1 d_loss : 0.387078
# batch 1 g_loss : 0.905290
# batch 2 d_loss : 0.380850
# batch 2 g_loss : 0.944903
# Epoch is 17
# Number of batches 3
# batch 0 d_loss : 0.369204
# batch 0 g_loss : 0.941748
# batch 1 d_loss : 0.387936
# batch 1 g_loss : 0.966839
# batch 2 d_loss : 0.370066
# batch 2 g_loss : 0.974966
# Epoch is 18
# Number of batches 3
# batch 0 d_loss : 0.327255
# batch 0 g_loss : 1.002131
# batch 1 d_loss : 0.371119
# batch 1 g_loss : 0.997233
# batch 2 d_loss : 0.331944
# batch 2 g_loss : 0.993595
# Epoch is 19
# Number of batches 3
# batch 0 d_loss : 0.345575
# batch 0 g_loss : 0.997807
# batch 1 d_loss : 0.374654
# batch 1 g_loss : 1.008405
# batch 2 d_loss : 0.347020
# batch 2 g_loss : 1.017157
# Epoch is 20
# Number of batches 3
# batch 0 d_loss : 0.304412
# batch 0 g_loss : 1.025303
# batch 1 d_loss : 0.337099
# batch 1 g_loss : 1.041659
# batch 2 d_loss : 0.334107
# batch 2 g_loss : 1.055585
# Epoch is 21
# Number of batches 3
# batch 0 d_loss : 0.303699
# batch 0 g_loss : 1.083071
# batch 1 d_loss : 0.317694
# batch 1 g_loss : 1.056947
# batch 2 d_loss : 0.303820
# batch 2 g_loss : 1.090680
# Epoch is 22
# Number of batches 3
# batch 0 d_loss : 0.302927
# batch 0 g_loss : 1.117888
# batch 1 d_loss : 0.314772
# batch 1 g_loss : 1.143392
# batch 2 d_loss : 0.297568
# batch 2 g_loss : 1.191097
# Epoch is 23
# Number of batches 3
# batch 0 d_loss : 0.295571
# batch 0 g_loss : 1.187258
# batch 1 d_loss : 0.306636
# batch 1 g_loss : 1.186640
# batch 2 d_loss : 0.289763
# batch 2 g_loss : 1.292667
# Epoch is 24
# Number of batches 3
# batch 0 d_loss : 0.275689
# batch 0 g_loss : 1.313168
# batch 1 d_loss : 0.291161
# batch 1 g_loss : 1.275683
# batch 2 d_loss : 0.270523
# batch 2 g_loss : 1.303986
# Epoch is 25
# Number of batches 3
# batch 0 d_loss : 0.264999
# batch 0 g_loss : 1.378585
# batch 1 d_loss : 0.301909
# batch 1 g_loss : 1.356964
# batch 2 d_loss : 0.251483
# batch 2 g_loss : 1.383756
# Epoch is 26
# Number of batches 3
# batch 0 d_loss : 0.254773
# batch 0 g_loss : 1.410005
# batch 1 d_loss : 0.296222
# batch 1 g_loss : 1.423877
# batch 2 d_loss : 0.248263
# batch 2 g_loss : 1.528936
# Epoch is 27
# Number of batches 3
# batch 0 d_loss : 0.239985
# batch 0 g_loss : 1.506063
# batch 1 d_loss : 0.275734
# batch 1 g_loss : 1.493041
# batch 2 d_loss : 0.213287
# batch 2 g_loss : 1.539212
# Epoch is 28
# Number of batches 3
# batch 0 d_loss : 0.221108
# batch 0 g_loss : 1.494678
# batch 1 d_loss : 0.253708
# batch 1 g_loss : 1.494285
# batch 2 d_loss : 0.242248
# batch 2 g_loss : 1.525746
# Epoch is 29
# Number of batches 3
# batch 0 d_loss : 0.197266
# batch 0 g_loss : 1.532752
# batch 1 d_loss : 0.248492
# batch 1 g_loss : 1.589191
# batch 2 d_loss : 0.203894
# batch 2 g_loss : 1.603183
# Epoch is 30
# Number of batches 3
# batch 0 d_loss : 0.205412
# batch 0 g_loss : 1.577005
# batch 1 d_loss : 0.241175
# batch 1 g_loss : 1.626455
# batch 2 d_loss : 0.213150
# batch 2 g_loss : 1.735078
# Epoch is 31
# Number of batches 3
# batch 0 d_loss : 0.200579
# batch 0 g_loss : 1.848225
# batch 1 d_loss : 0.244236
# batch 1 g_loss : 1.698863
# batch 2 d_loss : 0.187432
# batch 2 g_loss : 1.833513
# Epoch is 32
# Number of batches 3
# batch 0 d_loss : 0.180303
# batch 0 g_loss : 1.746128
# batch 1 d_loss : 0.241052
# batch 1 g_loss : 1.881380
# batch 2 d_loss : 0.172569
# batch 2 g_loss : 1.861650
# Epoch is 33
# Number of batches 3
# batch 0 d_loss : 0.171274
# batch 0 g_loss : 1.926233
# batch 1 d_loss : 0.224805
# batch 1 g_loss : 1.865472
# batch 2 d_loss : 0.179814
# batch 2 g_loss : 1.932157
# Epoch is 34
# Number of batches 3
# batch 0 d_loss : 0.143660
# batch 0 g_loss : 1.908674
# batch 1 d_loss : 0.207702
# batch 1 g_loss : 1.773306
# batch 2 d_loss : 0.152362
# batch 2 g_loss : 1.799414
# Epoch is 35
# Number of batches 3
# batch 0 d_loss : 0.144117
# batch 0 g_loss : 1.843093
# batch 1 d_loss : 0.196703
# batch 1 g_loss : 1.871228
# batch 2 d_loss : 0.168725
# batch 2 g_loss : 1.870739
# Epoch is 36
# Number of batches 3
# batch 0 d_loss : 0.135665
# batch 0 g_loss : 2.118911
# batch 1 d_loss : 0.237466
# batch 1 g_loss : 1.888659
# batch 2 d_loss : 0.163424
# batch 2 g_loss : 1.974064
# Epoch is 37
# Number of batches 3
# batch 0 d_loss : 0.138397
# batch 0 g_loss : 2.090464
# batch 1 d_loss : 0.205899
# batch 1 g_loss : 2.167172
# batch 2 d_loss : 0.159668
# batch 2 g_loss : 2.035622
# Epoch is 38
# Number of batches 3
# batch 0 d_loss : 0.135428
# batch 0 g_loss : 2.081890
# batch 1 d_loss : 0.200893
# batch 1 g_loss : 2.071524
# batch 2 d_loss : 0.137718
# batch 2 g_loss : 1.788826
# Epoch is 39
# Number of batches 3
# batch 0 d_loss : 0.145994
# batch 0 g_loss : 1.987581
# batch 1 d_loss : 0.236123
# batch 1 g_loss : 2.055083
# batch 2 d_loss : 0.204990
# batch 2 g_loss : 2.168262
# Epoch is 40
# Number of batches 3
# batch 0 d_loss : 0.172625
# batch 0 g_loss : 2.212880
# batch 1 d_loss : 0.276495
# batch 1 g_loss : 2.093883
# batch 2 d_loss : 0.154146
# batch 2 g_loss : 2.167173
# Epoch is 41
# Number of batches 3
# batch 0 d_loss : 0.154999
# batch 0 g_loss : 2.485377
# batch 1 d_loss : 0.298510
# batch 1 g_loss : 2.108556
# batch 2 d_loss : 0.143474
# batch 2 g_loss : 2.083572
# Epoch is 42
# Number of batches 3
# batch 0 d_loss : 0.212361
# batch 0 g_loss : 1.942520
# batch 1 d_loss : 0.278691
# batch 1 g_loss : 1.538845
# batch 2 d_loss : 0.163357
# batch 2 g_loss : 2.174891
# Epoch is 43
# Number of batches 3
# batch 0 d_loss : 0.187153
# batch 0 g_loss : 1.771315
# batch 1 d_loss : 0.243520
# batch 1 g_loss : 1.666151
# batch 2 d_loss : 0.272412
# batch 2 g_loss : 1.753939
# Epoch is 44
# Number of batches 3
# batch 0 d_loss : 0.182016
# batch 0 g_loss : 1.576890
# batch 1 d_loss : 0.325125
# batch 1 g_loss : 1.986897
# batch 2 d_loss : 0.226999
# batch 2 g_loss : 2.020735
# Epoch is 45
# Number of batches 3
# batch 0 d_loss : 0.258142
# batch 0 g_loss : 2.207211
# batch 1 d_loss : 0.354473
# batch 1 g_loss : 1.567649
# batch 2 d_loss : 0.226137
# batch 2 g_loss : 1.538327
# Epoch is 46
# Number of batches 3
# batch 0 d_loss : 0.172588
# batch 0 g_loss : 1.504658
# batch 1 d_loss : 0.343364
# batch 1 g_loss : 1.630019
# batch 2 d_loss : 0.233149
# batch 2 g_loss : 1.512147
# Epoch is 47
# Number of batches 3
# batch 0 d_loss : 0.468535
# batch 0 g_loss : 1.876883
# batch 1 d_loss : 0.384877
# batch 1 g_loss : 1.837154
# batch 2 d_loss : 0.269299
# batch 2 g_loss : 2.051969
# Epoch is 48
# Number of batches 3
# batch 0 d_loss : 0.250366
# batch 0 g_loss : 1.831412
# batch 1 d_loss : 0.568419
# batch 1 g_loss : 1.971026
# batch 2 d_loss : 0.241588
# batch 2 g_loss : 1.987864
# Epoch is 49
# Number of batches 3
# batch 0 d_loss : 0.330894
# batch 0 g_loss : 1.679456
# batch 1 d_loss : 0.459899
# batch 1 g_loss : 1.464130
# batch 2 d_loss : 0.343573
# batch 2 g_loss : 1.361872
# Epoch is 50
# Number of batches 3
# batch 0 d_loss : 0.293524
# batch 0 g_loss : 1.840747
# batch 1 d_loss : 0.412999
# batch 1 g_loss : 1.659335
# batch 2 d_loss : 0.229947
# batch 2 g_loss : 1.477249
# Epoch is 51
# Number of batches 3
# batch 0 d_loss : 0.242304
# batch 0 g_loss : 1.124150
# batch 1 d_loss : 0.394134
# batch 1 g_loss : 2.036394
# batch 2 d_loss : 0.405959
# batch 2 g_loss : 2.141508
# Epoch is 52
# Number of batches 3
# batch 0 d_loss : 0.325974
# batch 0 g_loss : 1.801249
# batch 1 d_loss : 0.448272
# batch 1 g_loss : 2.075379
# batch 2 d_loss : 0.259656
# batch 2 g_loss : 1.644734
# Epoch is 53
# Number of batches 3
# batch 0 d_loss : 0.275357
# batch 0 g_loss : 1.810744
# batch 1 d_loss : 0.383185
# batch 1 g_loss : 1.531651
# batch 2 d_loss : 0.418717
# batch 2 g_loss : 1.420643
# Epoch is 54
# Number of batches 3
# batch 0 d_loss : 0.321160
# batch 0 g_loss : 1.613418
# batch 1 d_loss : 0.373555
# batch 1 g_loss : 1.301897
# batch 2 d_loss : 0.277321
# batch 2 g_loss : 1.692594
# Epoch is 55
# Number of batches 3
# batch 0 d_loss : 0.243387
# batch 0 g_loss : 1.423481
# batch 1 d_loss : 0.352506
# batch 1 g_loss : 1.220753
# batch 2 d_loss : 0.333278
# batch 2 g_loss : 1.302174
# Epoch is 56
# Number of batches 3
# batch 0 d_loss : 0.389147
# batch 0 g_loss : 1.619676
# batch 1 d_loss : 0.475935
# batch 1 g_loss : 1.683915
# batch 2 d_loss : 0.351598
# batch 2 g_loss : 1.817376
# Epoch is 57
# Number of batches 3
# batch 0 d_loss : 0.391481
# batch 0 g_loss : 1.833724
# batch 1 d_loss : 0.403235
# batch 1 g_loss : 1.344043
# batch 2 d_loss : 0.341345
# batch 2 g_loss : 1.303218
# Epoch is 58
# Number of batches 3
# batch 0 d_loss : 0.301337
# batch 0 g_loss : 1.729722
# batch 1 d_loss : 0.427429
# batch 1 g_loss : 1.577810
# batch 2 d_loss : 0.299775
# batch 2 g_loss : 1.588485
# Epoch is 59
# Number of batches 3
# batch 0 d_loss : 0.269901
# batch 0 g_loss : 1.408050
# batch 1 d_loss : 0.440168
# batch 1 g_loss : 1.359444
# batch 2 d_loss : 0.245325
# batch 2 g_loss : 1.235641
# Epoch is 60
# Number of batches 3
# batch 0 d_loss : 0.344702
# batch 0 g_loss : 1.696306
# batch 1 d_loss : 0.419948
# batch 1 g_loss : 1.438012
# batch 2 d_loss : 0.340850
# batch 2 g_loss : 1.564819
# Epoch is 61
# Number of batches 3
# batch 0 d_loss : 0.315502
# batch 0 g_loss : 1.548444
# batch 1 d_loss : 0.407247
# batch 1 g_loss : 1.195617
# batch 2 d_loss : 0.342626
# batch 2 g_loss : 1.659941
# Epoch is 62
# Number of batches 3
# batch 0 d_loss : 0.356897
# batch 0 g_loss : 1.542034
# batch 1 d_loss : 0.414827
# batch 1 g_loss : 1.150602
# batch 2 d_loss : 0.321297
# batch 2 g_loss : 1.342187
# Epoch is 63
# Number of batches 3
# batch 0 d_loss : 0.302991
# batch 0 g_loss : 1.470472
# batch 1 d_loss : 0.446440
# batch 1 g_loss : 1.460404
# batch 2 d_loss : 0.346447
# batch 2 g_loss : 1.587319
# Epoch is 64
# Number of batches 3
# batch 0 d_loss : 0.355613
# batch 0 g_loss : 1.767393
# batch 1 d_loss : 0.454638
# batch 1 g_loss : 1.200006
# batch 2 d_loss : 0.319359
# batch 2 g_loss : 1.341417
# Epoch is 65
# Number of batches 3
# batch 0 d_loss : 0.375321
# batch 0 g_loss : 1.788576
# batch 1 d_loss : 0.467922
# batch 1 g_loss : 1.412260
# batch 2 d_loss : 0.309410
# batch 2 g_loss : 1.411029
# Epoch is 66
# Number of batches 3
# batch 0 d_loss : 0.278578
# batch 0 g_loss : 1.414757
# batch 1 d_loss : 0.461224
# batch 1 g_loss : 1.463168
# batch 2 d_loss : 0.299234
# batch 2 g_loss : 1.406671
# Epoch is 67
# Number of batches 3
# batch 0 d_loss : 0.302169
# batch 0 g_loss : 1.622528
# batch 1 d_loss : 0.420824
# batch 1 g_loss : 1.225583
# batch 2 d_loss : 0.308709
# batch 2 g_loss : 1.578576
# Epoch is 68
# Number of batches 3
# batch 0 d_loss : 0.330070
# batch 0 g_loss : 1.498097
# batch 1 d_loss : 0.440015
# batch 1 g_loss : 1.187381
# batch 2 d_loss : 0.387299
# batch 2 g_loss : 1.731866
# Epoch is 69
# Number of batches 3
# batch 0 d_loss : 0.352682
# batch 0 g_loss : 1.588783
# batch 1 d_loss : 0.433648
# batch 1 g_loss : 1.122860
# batch 2 d_loss : 0.386077
# batch 2 g_loss : 1.573397
# Epoch is 70
# Number of batches 3
# batch 0 d_loss : 0.362528
# batch 0 g_loss : 1.795953
# batch 1 d_loss : 0.487896
# batch 1 g_loss : 1.289073
# batch 2 d_loss : 0.299947
# batch 2 g_loss : 1.502941
# Epoch is 71
# Number of batches 3
# batch 0 d_loss : 0.372577
# batch 0 g_loss : 1.894870
# batch 1 d_loss : 0.437273
# batch 1 g_loss : 1.225966
# batch 2 d_loss : 0.376738
# batch 2 g_loss : 1.816370
# Epoch is 72
# Number of batches 3
# batch 0 d_loss : 0.362790
# batch 0 g_loss : 1.793226
# batch 1 d_loss : 0.470623
# batch 1 g_loss : 1.145463
# batch 2 d_loss : 0.260312
# batch 2 g_loss : 1.503417
# Epoch is 73
# Number of batches 3
# batch 0 d_loss : 0.455983
# batch 0 g_loss : 2.334688
# batch 1 d_loss : 0.515334
# batch 1 g_loss : 1.386740
# batch 2 d_loss : 0.278075
# batch 2 g_loss : 1.040696
# Epoch is 74
# Number of batches 3
# batch 0 d_loss : 0.341563
# batch 0 g_loss : 1.745937
# batch 1 d_loss : 0.502103
# batch 1 g_loss : 1.450698
# batch 2 d_loss : 0.302333
# batch 2 g_loss : 1.445718
# Epoch is 75
# Number of batches 3
# batch 0 d_loss : 0.274545
# batch 0 g_loss : 1.212560
# batch 1 d_loss : 0.503962
# batch 1 g_loss : 1.465961
# batch 2 d_loss : 0.305056
# batch 2 g_loss : 1.647247
# Epoch is 76
# Number of batches 3
# batch 0 d_loss : 0.305517
# batch 0 g_loss : 1.668272
# batch 1 d_loss : 0.514821
# batch 1 g_loss : 1.164780
# batch 2 d_loss : 0.335686
# batch 2 g_loss : 1.340770
# Epoch is 77
# Number of batches 3
# batch 0 d_loss : 0.290935
# batch 0 g_loss : 1.708714
# batch 1 d_loss : 0.431688
# batch 1 g_loss : 0.816967
# batch 2 d_loss : 0.387089
# batch 2 g_loss : 1.634184
# Epoch is 78
# Number of batches 3
# batch 0 d_loss : 0.317939
# batch 0 g_loss : 1.820824
# batch 1 d_loss : 0.425895
# batch 1 g_loss : 1.054201
# batch 2 d_loss : 0.325275
# batch 2 g_loss : 1.656738
# Epoch is 79
# Number of batches 3
# batch 0 d_loss : 0.417654
# batch 0 g_loss : 2.083665
# batch 1 d_loss : 0.570282
# batch 1 g_loss : 1.660930
# batch 2 d_loss : 0.287584
# batch 2 g_loss : 1.702904
# Epoch is 80
# Number of batches 3
# batch 0 d_loss : 0.355516
# batch 0 g_loss : 1.825628
# batch 1 d_loss : 0.500081
# batch 1 g_loss : 1.264152
# batch 2 d_loss : 0.306425
# batch 2 g_loss : 1.397412
# Epoch is 81
# Number of batches 3
# batch 0 d_loss : 0.326231
# batch 0 g_loss : 1.708530
# batch 1 d_loss : 0.475992
# batch 1 g_loss : 1.218904
# batch 2 d_loss : 0.340589
# batch 2 g_loss : 1.634659
# Epoch is 82
# Number of batches 3
# batch 0 d_loss : 0.316818
# batch 0 g_loss : 1.606382
# batch 1 d_loss : 0.540881
# batch 1 g_loss : 1.406508
# batch 2 d_loss : 0.291674
# batch 2 g_loss : 1.933694
# Epoch is 83
# Number of batches 3
# batch 0 d_loss : 0.324521
# batch 0 g_loss : 1.449204
# batch 1 d_loss : 0.455336
# batch 1 g_loss : 1.128997
# batch 2 d_loss : 0.345993
# batch 2 g_loss : 1.440465
# Epoch is 84
# Number of batches 3
# batch 0 d_loss : 0.327203
# batch 0 g_loss : 2.028578
# batch 1 d_loss : 0.454315
# batch 1 g_loss : 1.250768
# batch 2 d_loss : 0.391025
# batch 2 g_loss : 1.620749
# Epoch is 85
# Number of batches 3
# batch 0 d_loss : 0.320755
# batch 0 g_loss : 1.503064
# batch 1 d_loss : 0.465459
# batch 1 g_loss : 0.954731
# batch 2 d_loss : 0.307623
# batch 2 g_loss : 1.264161
# Epoch is 86
# Number of batches 3
# batch 0 d_loss : 0.285504
# batch 0 g_loss : 1.483779
# batch 1 d_loss : 0.498924
# batch 1 g_loss : 1.198457
# batch 2 d_loss : 0.347604
# batch 2 g_loss : 1.380280
# Epoch is 87
# Number of batches 3
# batch 0 d_loss : 0.349260
# batch 0 g_loss : 2.026410
# batch 1 d_loss : 0.547920
# batch 1 g_loss : 1.121508
# batch 2 d_loss : 0.340914
# batch 2 g_loss : 1.469392
# Epoch is 88
# Number of batches 3
# batch 0 d_loss : 0.343521
# batch 0 g_loss : 1.807838
# batch 1 d_loss : 0.498713
# batch 1 g_loss : 0.979971
# batch 2 d_loss : 0.279845
# batch 2 g_loss : 1.231409
# Epoch is 89
# Number of batches 3
# batch 0 d_loss : 0.372397
# batch 0 g_loss : 2.033331
# batch 1 d_loss : 0.498883
# batch 1 g_loss : 1.261603
# batch 2 d_loss : 0.410349
# batch 2 g_loss : 1.630259
# Epoch is 90
# Number of batches 3
# batch 0 d_loss : 0.316614
# batch 0 g_loss : 1.398004
# batch 1 d_loss : 0.516682
# batch 1 g_loss : 1.319223
# batch 2 d_loss : 0.267974
# batch 2 g_loss : 1.343739
# Epoch is 91
# Number of batches 3
# batch 0 d_loss : 0.334651
# batch 0 g_loss : 1.838580
# batch 1 d_loss : 0.511542
# batch 1 g_loss : 1.292312
# batch 2 d_loss : 0.316891
# batch 2 g_loss : 1.435438
# Epoch is 92
# Number of batches 3
# batch 0 d_loss : 0.384857
# batch 0 g_loss : 2.020541
# batch 1 d_loss : 0.560904
# batch 1 g_loss : 1.503998
# batch 2 d_loss : 0.321598
# batch 2 g_loss : 1.352675
# Epoch is 93
# Number of batches 3
# batch 0 d_loss : 0.284597
# batch 0 g_loss : 1.360533
# batch 1 d_loss : 0.544798
# batch 1 g_loss : 1.686302
# batch 2 d_loss : 0.352053
# batch 2 g_loss : 1.621223
# Epoch is 94
# Number of batches 3
# batch 0 d_loss : 0.362704
# batch 0 g_loss : 1.753868
# batch 1 d_loss : 0.499504
# batch 1 g_loss : 1.029271
# batch 2 d_loss : 0.343098
# batch 2 g_loss : 1.388408
# Epoch is 95
# Number of batches 3
# batch 0 d_loss : 0.328020
# batch 0 g_loss : 1.737226
# batch 1 d_loss : 0.513596
# batch 1 g_loss : 1.218768
# batch 2 d_loss : 0.427038
# batch 2 g_loss : 2.042945
# Epoch is 96
# Number of batches 3
# batch 0 d_loss : 0.328938
# batch 0 g_loss : 1.340399
# batch 1 d_loss : 0.420794
# batch 1 g_loss : 0.693982
# batch 2 d_loss : 0.571588
# batch 2 g_loss : 2.209652
# Epoch is 97
# Number of batches 3
# batch 0 d_loss : 0.432367
# batch 0 g_loss : 1.773054
# batch 1 d_loss : 0.537485
# batch 1 g_loss : 0.722110
# batch 2 d_loss : 0.347585
# batch 2 g_loss : 1.127802
# Epoch is 98
# Number of batches 3
# batch 0 d_loss : 0.362406
# batch 0 g_loss : 1.481736
# batch 1 d_loss : 0.515174
# batch 1 g_loss : 1.274714
# batch 2 d_loss : 0.402279
# batch 2 g_loss : 1.544096
# Epoch is 99
# Number of batches 3
# batch 0 d_loss : 0.304076
# batch 0 g_loss : 1.319481
# batch 1 d_loss : 0.570994
# batch 1 g_loss : 1.472581
# batch 2 d_loss : 0.387111
# batch 2 g_loss : 1.388842
# Epoch is 100
# Number of batches 3
# batch 0 d_loss : 0.373245
# batch 0 g_loss : 1.882179
# batch 1 d_loss : 0.547742
# batch 1 g_loss : 1.126793
# batch 2 d_loss : 0.379276
# batch 2 g_loss : 1.770750
# Epoch is 101
# Number of batches 3
# batch 0 d_loss : 0.401316
# batch 0 g_loss : 1.967987
# batch 1 d_loss : 0.555234
# batch 1 g_loss : 0.982240
# batch 2 d_loss : 0.492346
# batch 2 g_loss : 1.897168
# Epoch is 102
# Number of batches 3
# batch 0 d_loss : 0.368839
# batch 0 g_loss : 1.777176
# batch 1 d_loss : 0.500544
# batch 1 g_loss : 0.605838
# batch 2 d_loss : 0.465961
# batch 2 g_loss : 1.990195
# Epoch is 103
# Number of batches 3
# batch 0 d_loss : 0.355445
# batch 0 g_loss : 1.648616
# batch 1 d_loss : 0.496597
# batch 1 g_loss : 1.092875
# batch 2 d_loss : 0.446367
# batch 2 g_loss : 1.601494
# Epoch is 104
# Number of batches 3
# batch 0 d_loss : 0.313813
# batch 0 g_loss : 1.646688
# batch 1 d_loss : 0.583400
# batch 1 g_loss : 1.722217
# batch 2 d_loss : 0.419243
# batch 2 g_loss : 1.745951
# Epoch is 105
# Number of batches 3
# batch 0 d_loss : 0.360377
# batch 0 g_loss : 1.519363
# batch 1 d_loss : 0.503365
# batch 1 g_loss : 0.991002
# batch 2 d_loss : 0.376587
# batch 2 g_loss : 1.462608
# Epoch is 106
# Number of batches 3
# batch 0 d_loss : 0.329519
# batch 0 g_loss : 1.951198
# batch 1 d_loss : 0.554481
# batch 1 g_loss : 1.077989
# batch 2 d_loss : 0.318864
# batch 2 g_loss : 1.283091
# Epoch is 107
# Number of batches 3
# batch 0 d_loss : 0.342524
# batch 0 g_loss : 1.835053
# batch 1 d_loss : 0.541242
# batch 1 g_loss : 1.235698
# batch 2 d_loss : 0.333706
# batch 2 g_loss : 1.501479
# Epoch is 108
# Number of batches 3
# batch 0 d_loss : 0.305996
# batch 0 g_loss : 1.103555
# batch 1 d_loss : 0.504958
# batch 1 g_loss : 1.354107
# batch 2 d_loss : 0.461946
# batch 2 g_loss : 1.898105
# Epoch is 109
# Number of batches 3
# batch 0 d_loss : 0.376794
# batch 0 g_loss : 1.811703
# batch 1 d_loss : 0.515747
# batch 1 g_loss : 0.784309
# batch 2 d_loss : 0.500058
# batch 2 g_loss : 1.803130
# Epoch is 110
# Number of batches 3
# batch 0 d_loss : 0.352492
# batch 0 g_loss : 1.473141
# batch 1 d_loss : 0.557369
# batch 1 g_loss : 1.449692
# batch 2 d_loss : 0.354684
# batch 2 g_loss : 1.811095
# Epoch is 111
# Number of batches 3
# batch 0 d_loss : 0.450626
# batch 0 g_loss : 1.501524
# batch 1 d_loss : 0.549498
# batch 1 g_loss : 0.928746
# batch 2 d_loss : 0.382408
# batch 2 g_loss : 1.478182
# Epoch is 112
# Number of batches 3
# batch 0 d_loss : 0.362665
# batch 0 g_loss : 1.631486
# batch 1 d_loss : 0.549968
# batch 1 g_loss : 1.134334
# batch 2 d_loss : 0.382520
# batch 2 g_loss : 1.587456
# Epoch is 113
# Number of batches 3
# batch 0 d_loss : 0.460785
# batch 0 g_loss : 2.018585
# batch 1 d_loss : 0.666776
# batch 1 g_loss : 1.526690
# batch 2 d_loss : 0.320100
# batch 2 g_loss : 0.958716
# Epoch is 114
# Number of batches 3
# batch 0 d_loss : 0.396942
# batch 0 g_loss : 1.646466
# batch 1 d_loss : 0.525174
# batch 1 g_loss : 1.174450
# batch 2 d_loss : 0.380679
# batch 2 g_loss : 1.515968
# Epoch is 115
# Number of batches 3
# batch 0 d_loss : 0.346714
# batch 0 g_loss : 1.690149
# batch 1 d_loss : 0.610738
# batch 1 g_loss : 1.470734
# batch 2 d_loss : 0.396984
# batch 2 g_loss : 1.490640
# Epoch is 116
# Number of batches 3
# batch 0 d_loss : 0.380433
# batch 0 g_loss : 1.451205
# batch 1 d_loss : 0.471755
# batch 1 g_loss : 0.681038
# batch 2 d_loss : 0.398333
# batch 2 g_loss : 1.422206
# Epoch is 117
# Number of batches 3
# batch 0 d_loss : 0.337962
# batch 0 g_loss : 1.543257
# batch 1 d_loss : 0.561409
# batch 1 g_loss : 1.219790
# batch 2 d_loss : 0.344455
# batch 2 g_loss : 1.151429
# Epoch is 118
# Number of batches 3
# batch 0 d_loss : 0.398535
# batch 0 g_loss : 1.878980
# batch 1 d_loss : 0.559927
# batch 1 g_loss : 1.161058
# batch 2 d_loss : 0.349679
# batch 2 g_loss : 1.365605
# Epoch is 119
# Number of batches 3
# batch 0 d_loss : 0.300824
# batch 0 g_loss : 1.525916
# batch 1 d_loss : 0.567062
# batch 1 g_loss : 1.353182
# batch 2 d_loss : 0.416501
# batch 2 g_loss : 1.775806
# Epoch is 120
# Number of batches 3
# batch 0 d_loss : 0.398915
# batch 0 g_loss : 1.798521
# batch 1 d_loss : 0.577645
# batch 1 g_loss : 1.265208
# batch 2 d_loss : 0.346048
# batch 2 g_loss : 1.128767
# Epoch is 121
# Number of batches 3
# batch 0 d_loss : 0.408864
# batch 0 g_loss : 1.556048
# batch 1 d_loss : 0.542657
# batch 1 g_loss : 1.192838
# batch 2 d_loss : 0.365870
# batch 2 g_loss : 1.799167
# Epoch is 122
# Number of batches 3
# batch 0 d_loss : 0.412951
# batch 0 g_loss : 1.594074
# batch 1 d_loss : 0.545370
# batch 1 g_loss : 1.380260
# batch 2 d_loss : 0.374817
# batch 2 g_loss : 1.321953
# Epoch is 123
# Number of batches 3
# batch 0 d_loss : 0.375155
# batch 0 g_loss : 1.526166
# batch 1 d_loss : 0.513291
# batch 1 g_loss : 0.968715
# batch 2 d_loss : 0.409911
# batch 2 g_loss : 1.368443
# Epoch is 124
# Number of batches 3
# batch 0 d_loss : 0.356852
# batch 0 g_loss : 1.363170
# batch 1 d_loss : 0.474494
# batch 1 g_loss : 1.124241
# batch 2 d_loss : 0.340004
# batch 2 g_loss : 1.430849
# Epoch is 125
# Number of batches 3
# batch 0 d_loss : 0.366700
# batch 0 g_loss : 1.745788
# batch 1 d_loss : 0.522079
# batch 1 g_loss : 1.022413
# batch 2 d_loss : 0.430589
# batch 2 g_loss : 1.708459
# Epoch is 126
# Number of batches 3
# batch 0 d_loss : 0.344089
# batch 0 g_loss : 1.572504
# batch 1 d_loss : 0.500609
# batch 1 g_loss : 1.186819
# batch 2 d_loss : 0.360729
# batch 2 g_loss : 1.197847
# Epoch is 127
# Number of batches 3
# batch 0 d_loss : 0.368403
# batch 0 g_loss : 1.603705
# batch 1 d_loss : 0.499766
# batch 1 g_loss : 1.092245
# batch 2 d_loss : 0.494084
# batch 2 g_loss : 1.846500
# Epoch is 128
# Number of batches 3
# batch 0 d_loss : 0.353208
# batch 0 g_loss : 1.149435
# batch 1 d_loss : 0.565518
# batch 1 g_loss : 0.967157
# batch 2 d_loss : 0.352722
# batch 2 g_loss : 1.326658
# Epoch is 129
# Number of batches 3
# batch 0 d_loss : 0.297280
# batch 0 g_loss : 1.150137
# batch 1 d_loss : 0.631114
# batch 1 g_loss : 1.881957
# batch 2 d_loss : 0.369344
# batch 2 g_loss : 1.073622
# Epoch is 130
# Number of batches 3
# batch 0 d_loss : 0.336073
# batch 0 g_loss : 1.115584
# batch 1 d_loss : 0.505435
# batch 1 g_loss : 0.891999
# batch 2 d_loss : 0.379527
# batch 2 g_loss : 1.677012
# Epoch is 131
# Number of batches 3
# batch 0 d_loss : 0.462787
# batch 0 g_loss : 2.100846
# batch 1 d_loss : 0.603409
# batch 1 g_loss : 1.299766
# batch 2 d_loss : 0.407269
# batch 2 g_loss : 1.633921
# Epoch is 132
# Number of batches 3
# batch 0 d_loss : 0.433889
# batch 0 g_loss : 2.108929
# batch 1 d_loss : 0.559545
# batch 1 g_loss : 1.360098
# batch 2 d_loss : 0.381154
# batch 2 g_loss : 1.687176
# Epoch is 133
# Number of batches 3
# batch 0 d_loss : 0.390566
# batch 0 g_loss : 1.415126
# batch 1 d_loss : 0.522483
# batch 1 g_loss : 1.253942
# batch 2 d_loss : 0.359526
# batch 2 g_loss : 1.469913
# Epoch is 134
# Number of batches 3
# batch 0 d_loss : 0.468016
# batch 0 g_loss : 1.875708
# batch 1 d_loss : 0.595144
# batch 1 g_loss : 1.305961
# batch 2 d_loss : 0.379579
# batch 2 g_loss : 1.369861
# Epoch is 135
# Number of batches 3
# batch 0 d_loss : 0.474346
# batch 0 g_loss : 2.281777
# batch 1 d_loss : 0.606340
# batch 1 g_loss : 1.192972
# batch 2 d_loss : 0.333040
# batch 2 g_loss : 1.112875
# Epoch is 136
# Number of batches 3
# batch 0 d_loss : 0.332009
# batch 0 g_loss : 0.930281
# batch 1 d_loss : 0.545764
# batch 1 g_loss : 1.406586
# batch 2 d_loss : 0.326169
# batch 2 g_loss : 1.135908
# Epoch is 137
# Number of batches 3
# batch 0 d_loss : 0.360070
# batch 0 g_loss : 1.455106
# batch 1 d_loss : 0.722762
# batch 1 g_loss : 2.181296
# batch 2 d_loss : 0.430844
# batch 2 g_loss : 1.542106
# Epoch is 138
# Number of batches 3
# batch 0 d_loss : 0.382924
# batch 0 g_loss : 1.630956
# batch 1 d_loss : 0.494157
# batch 1 g_loss : 1.252193
# batch 2 d_loss : 0.526177
# batch 2 g_loss : 1.760917
# Epoch is 139
# Number of batches 3
# batch 0 d_loss : 0.375886
# batch 0 g_loss : 1.492342
# batch 1 d_loss : 0.514327
# batch 1 g_loss : 1.588674
# batch 2 d_loss : 0.328619
# batch 2 g_loss : 1.595918
# Epoch is 140
# Number of batches 3
# batch 0 d_loss : 0.426173
# batch 0 g_loss : 1.665999
# batch 1 d_loss : 0.519363
# batch 1 g_loss : 1.270731
# batch 2 d_loss : 0.380925
# batch 2 g_loss : 1.704880
# Epoch is 141
# Number of batches 3
# batch 0 d_loss : 0.334613
# batch 0 g_loss : 1.279300
# batch 1 d_loss : 0.471848
# batch 1 g_loss : 1.158399
# batch 2 d_loss : 0.434219
# batch 2 g_loss : 1.832064
# Epoch is 142
# Number of batches 3
# batch 0 d_loss : 0.398113
# batch 0 g_loss : 1.820141
# batch 1 d_loss : 0.523241
# batch 1 g_loss : 1.067770
# batch 2 d_loss : 0.363604
# batch 2 g_loss : 1.550488
# Epoch is 143
# Number of batches 3
# batch 0 d_loss : 0.575222
# batch 0 g_loss : 2.038824
# batch 1 d_loss : 0.615229
# batch 1 g_loss : 1.508298
# batch 2 d_loss : 0.334079
# batch 2 g_loss : 1.414972
# Epoch is 144
# Number of batches 3
# batch 0 d_loss : 0.399414
# batch 0 g_loss : 1.698998
# batch 1 d_loss : 0.633311
# batch 1 g_loss : 1.550946
# batch 2 d_loss : 0.367065
# batch 2 g_loss : 1.496135
# Epoch is 145
# Number of batches 3
# batch 0 d_loss : 0.428010
# batch 0 g_loss : 1.509598
# batch 1 d_loss : 0.534239
# batch 1 g_loss : 1.422308
# batch 2 d_loss : 0.346175
# batch 2 g_loss : 1.478306
# Epoch is 146
# Number of batches 3
# batch 0 d_loss : 0.330280
# batch 0 g_loss : 1.187970
# batch 1 d_loss : 0.550240
# batch 1 g_loss : 1.819336
# batch 2 d_loss : 0.404917
# batch 2 g_loss : 1.767545
# Epoch is 147
# Number of batches 3
# batch 0 d_loss : 0.388052
# batch 0 g_loss : 2.001866
# batch 1 d_loss : 0.505106
# batch 1 g_loss : 1.343672
# batch 2 d_loss : 0.289224
# batch 2 g_loss : 1.183318
# Epoch is 148
# Number of batches 3
# batch 0 d_loss : 0.441493
# batch 0 g_loss : 1.763599
# batch 1 d_loss : 0.581015
# batch 1 g_loss : 1.890514
# batch 2 d_loss : 0.402275
# batch 2 g_loss : 1.459605
# Epoch is 149
# Number of batches 3
# batch 0 d_loss : 0.289418
# batch 0 g_loss : 1.177591
# batch 1 d_loss : 0.478615
# batch 1 g_loss : 1.173372
# batch 2 d_loss : 0.464395
# batch 2 g_loss : 1.605289
# Epoch is 150
# Number of batches 3
# batch 0 d_loss : 0.376341
# batch 0 g_loss : 1.818205
# batch 1 d_loss : 0.471903
# batch 1 g_loss : 0.911905
# batch 2 d_loss : 0.403381
# batch 2 g_loss : 1.801671
# Epoch is 151
# Number of batches 3
# batch 0 d_loss : 0.322790
# batch 0 g_loss : 1.296561
# batch 1 d_loss : 0.458670
# batch 1 g_loss : 1.332654
# batch 2 d_loss : 0.487145
# batch 2 g_loss : 1.765442
# Epoch is 152
# Number of batches 3
# batch 0 d_loss : 0.405596
# batch 0 g_loss : 1.867617
# batch 1 d_loss : 0.513000
# batch 1 g_loss : 1.135027
# batch 2 d_loss : 0.348553
# batch 2 g_loss : 1.499174
# Epoch is 153
# Number of batches 3
# batch 0 d_loss : 0.321172
# batch 0 g_loss : 1.765381
# batch 1 d_loss : 0.582220
# batch 1 g_loss : 1.492671
# batch 2 d_loss : 0.299610
# batch 2 g_loss : 0.953436
# Epoch is 154
# Number of batches 3
# batch 0 d_loss : 0.291638
# batch 0 g_loss : 0.690855
# batch 1 d_loss : 0.546696
# batch 1 g_loss : 1.662413
# batch 2 d_loss : 0.342232
# batch 2 g_loss : 1.524576
# Epoch is 155
# Number of batches 3
# batch 0 d_loss : 0.480290
# batch 0 g_loss : 2.312928
# batch 1 d_loss : 0.520651
# batch 1 g_loss : 0.753830
# batch 2 d_loss : 0.544306
# batch 2 g_loss : 1.705621
# Epoch is 156
# Number of batches 3
# batch 0 d_loss : 0.363462
# batch 0 g_loss : 1.516337
# batch 1 d_loss : 0.620821
# batch 1 g_loss : 1.195110
# batch 2 d_loss : 0.461635
# batch 2 g_loss : 1.582127
# Epoch is 157
# Number of batches 3
# batch 0 d_loss : 0.369111
# batch 0 g_loss : 1.478703
# batch 1 d_loss : 0.494754
# batch 1 g_loss : 1.060497
# batch 2 d_loss : 0.261874
# batch 2 g_loss : 0.882459
# Epoch is 158
# Number of batches 3
# batch 0 d_loss : 0.415889
# batch 0 g_loss : 1.745774
# batch 1 d_loss : 0.551617
# batch 1 g_loss : 1.387684
# batch 2 d_loss : 0.375958
# batch 2 g_loss : 1.422583
# Epoch is 159
# Number of batches 3
# batch 0 d_loss : 0.424619
# batch 0 g_loss : 1.582854
# batch 1 d_loss : 0.535871
# batch 1 g_loss : 1.120997
# batch 2 d_loss : 0.429078
# batch 2 g_loss : 1.873715
# Epoch is 160
# Number of batches 3
# batch 0 d_loss : 0.426631
# batch 0 g_loss : 1.667462
# batch 1 d_loss : 0.517857
# batch 1 g_loss : 1.262001
# batch 2 d_loss : 0.405844
# batch 2 g_loss : 1.641837
# Epoch is 161
# Number of batches 3
# batch 0 d_loss : 0.399378
# batch 0 g_loss : 1.707127
# batch 1 d_loss : 0.490751
# batch 1 g_loss : 1.023580
# batch 2 d_loss : 0.324483
# batch 2 g_loss : 1.247751
# Epoch is 162
# Number of batches 3
# batch 0 d_loss : 0.446900
# batch 0 g_loss : 1.472874
# batch 1 d_loss : 0.539905
# batch 1 g_loss : 1.395111
# batch 2 d_loss : 0.513110
# batch 2 g_loss : 1.839710
# Epoch is 163
# Number of batches 3
# batch 0 d_loss : 0.472099
# batch 0 g_loss : 1.717349
# batch 1 d_loss : 0.527572
# batch 1 g_loss : 0.749032
# batch 2 d_loss : 0.321679
# batch 2 g_loss : 1.024987
# Epoch is 164
# Number of batches 3
# batch 0 d_loss : 0.456834
# batch 0 g_loss : 1.629754
# batch 1 d_loss : 0.558374
# batch 1 g_loss : 1.356672
# batch 2 d_loss : 0.310972
# batch 2 g_loss : 0.935257
# Epoch is 165
# Number of batches 3
# batch 0 d_loss : 0.415605
# batch 0 g_loss : 1.443625
# batch 1 d_loss : 0.575953
# batch 1 g_loss : 1.285282
# batch 2 d_loss : 0.394181
# batch 2 g_loss : 1.599546
# Epoch is 166
# Number of batches 3
# batch 0 d_loss : 0.377672
# batch 0 g_loss : 1.210312
# batch 1 d_loss : 0.604400
# batch 1 g_loss : 1.521252
# batch 2 d_loss : 0.381761
# batch 2 g_loss : 1.380645
# Epoch is 167
# Number of batches 3
# batch 0 d_loss : 0.520756
# batch 0 g_loss : 2.443935
# batch 1 d_loss : 0.648824
# batch 1 g_loss : 1.239493
# batch 2 d_loss : 0.476415
# batch 2 g_loss : 1.979773
# Epoch is 168
# Number of batches 3
# batch 0 d_loss : 0.590240
# batch 0 g_loss : 1.741240
# batch 1 d_loss : 0.625365
# batch 1 g_loss : 1.120577
# batch 2 d_loss : 0.506023
# batch 2 g_loss : 1.737349
# Epoch is 169
# Number of batches 3
# batch 0 d_loss : 0.418903
# batch 0 g_loss : 1.616239
# batch 1 d_loss : 0.549303
# batch 1 g_loss : 0.969886
# batch 2 d_loss : 0.454229
# batch 2 g_loss : 1.657931
# Epoch is 170
# Number of batches 3
# batch 0 d_loss : 0.364162
# batch 0 g_loss : 1.217679
# batch 1 d_loss : 0.475297
# batch 1 g_loss : 1.090803
# batch 2 d_loss : 0.466854
# batch 2 g_loss : 1.686264
# Epoch is 171
# Number of batches 3
# batch 0 d_loss : 0.327774
# batch 0 g_loss : 1.168544
# batch 1 d_loss : 0.548332
# batch 1 g_loss : 1.315075
# batch 2 d_loss : 0.287544
# batch 2 g_loss : 1.362020
# Epoch is 172
# Number of batches 3
# batch 0 d_loss : 0.392212
# batch 0 g_loss : 1.878322
# batch 1 d_loss : 0.484977
# batch 1 g_loss : 1.405187
# batch 2 d_loss : 0.367902
# batch 2 g_loss : 1.408204
# Epoch is 173
# Number of batches 3
# batch 0 d_loss : 0.367482
# batch 0 g_loss : 1.550308
# batch 1 d_loss : 0.515251
# batch 1 g_loss : 1.314390
# batch 2 d_loss : 0.446286
# batch 2 g_loss : 1.867317
# Epoch is 174
# Number of batches 3
# batch 0 d_loss : 0.382444
# batch 0 g_loss : 1.527740
# batch 1 d_loss : 0.516418
# batch 1 g_loss : 1.518544
# batch 2 d_loss : 0.442012
# batch 2 g_loss : 1.291129
# Epoch is 175
# Number of batches 3
# batch 0 d_loss : 0.428508
# batch 0 g_loss : 1.728397
# batch 1 d_loss : 0.558034
# batch 1 g_loss : 1.641613
# batch 2 d_loss : 0.451374
# batch 2 g_loss : 1.755517
# Epoch is 176
# Number of batches 3
# batch 0 d_loss : 0.456773
# batch 0 g_loss : 1.790547
# batch 1 d_loss : 0.561193
# batch 1 g_loss : 1.219506
# batch 2 d_loss : 0.354556
# batch 2 g_loss : 1.337872
# Epoch is 177
# Number of batches 3
# batch 0 d_loss : 0.479739
# batch 0 g_loss : 1.786832
# batch 1 d_loss : 0.551933
# batch 1 g_loss : 1.111908
# batch 2 d_loss : 0.407777
# batch 2 g_loss : 1.072818
# Epoch is 178
# Number of batches 3
# batch 0 d_loss : 0.403772
# batch 0 g_loss : 1.501850
# batch 1 d_loss : 0.501693
# batch 1 g_loss : 0.887728
# batch 2 d_loss : 0.475423
# batch 2 g_loss : 1.750682
# Epoch is 179
# Number of batches 3
# batch 0 d_loss : 0.337457
# batch 0 g_loss : 1.034905
# batch 1 d_loss : 0.640467
# batch 1 g_loss : 1.602565
# batch 2 d_loss : 0.382898
# batch 2 g_loss : 1.225313
# Epoch is 180
# Number of batches 3
# batch 0 d_loss : 0.370324
# batch 0 g_loss : 1.405843
# batch 1 d_loss : 0.535484
# batch 1 g_loss : 1.482131
# batch 2 d_loss : 0.359390
# batch 2 g_loss : 1.284708
# Epoch is 181
# Number of batches 3
# batch 0 d_loss : 0.434807
# batch 0 g_loss : 1.829591
# batch 1 d_loss : 0.539510
# batch 1 g_loss : 1.008741
# batch 2 d_loss : 0.353539
# batch 2 g_loss : 1.333303
# Epoch is 182
# Number of batches 3
# batch 0 d_loss : 0.404274
# batch 0 g_loss : 1.527757
# batch 1 d_loss : 0.549804
# batch 1 g_loss : 1.414077
# batch 2 d_loss : 0.458979
# batch 2 g_loss : 1.834369
# Epoch is 183
# Number of batches 3
# batch 0 d_loss : 0.450309
# batch 0 g_loss : 2.058507
# batch 1 d_loss : 0.565846
# batch 1 g_loss : 1.266973
# batch 2 d_loss : 0.347867
# batch 2 g_loss : 1.341898
# Epoch is 184
# Number of batches 3
# batch 0 d_loss : 0.331590
# batch 0 g_loss : 1.743635
# batch 1 d_loss : 0.593252
# batch 1 g_loss : 1.453568
# batch 2 d_loss : 0.360365
# batch 2 g_loss : 1.421882
# Epoch is 185
# Number of batches 3
# batch 0 d_loss : 0.404388
# batch 0 g_loss : 1.409365
# batch 1 d_loss : 0.554249
# batch 1 g_loss : 1.296256
# batch 2 d_loss : 0.461183
# batch 2 g_loss : 2.014494
# Epoch is 186
# Number of batches 3
# batch 0 d_loss : 0.367235
# batch 0 g_loss : 1.556229
# batch 1 d_loss : 0.527862
# batch 1 g_loss : 1.261949
# batch 2 d_loss : 0.440594
# batch 2 g_loss : 1.683928
# Epoch is 187
# Number of batches 3
# batch 0 d_loss : 0.375680
# batch 0 g_loss : 1.711005
# batch 1 d_loss : 0.637565
# batch 1 g_loss : 1.493623
# batch 2 d_loss : 0.386270
# batch 2 g_loss : 1.745020
# Epoch is 188
# Number of batches 3
# batch 0 d_loss : 0.306467
# batch 0 g_loss : 1.370043
# batch 1 d_loss : 0.574995
# batch 1 g_loss : 1.510697
# batch 2 d_loss : 0.297083
# batch 2 g_loss : 1.102580
# Epoch is 189
# Number of batches 3
# batch 0 d_loss : 0.425512
# batch 0 g_loss : 1.893148
# batch 1 d_loss : 0.565146
# batch 1 g_loss : 1.792961
# batch 2 d_loss : 0.422632
# batch 2 g_loss : 1.673808
# Epoch is 190
# Number of batches 3
# batch 0 d_loss : 0.389181
# batch 0 g_loss : 1.929345
# batch 1 d_loss : 0.521077
# batch 1 g_loss : 0.887818
# batch 2 d_loss : 0.523364
# batch 2 g_loss : 2.194359
# Epoch is 191
# Number of batches 3
# batch 0 d_loss : 0.377631
# batch 0 g_loss : 1.253430
# batch 1 d_loss : 0.545362
# batch 1 g_loss : 1.295736
# batch 2 d_loss : 0.421518
# batch 2 g_loss : 1.478688
# Epoch is 192
# Number of batches 3
# batch 0 d_loss : 0.360076
# batch 0 g_loss : 1.704941
# batch 1 d_loss : 0.541595
# batch 1 g_loss : 1.039198
# batch 2 d_loss : 0.409979
# batch 2 g_loss : 1.535706
# Epoch is 193
# Number of batches 3
# batch 0 d_loss : 0.358159
# batch 0 g_loss : 1.697002
# batch 1 d_loss : 0.582012
# batch 1 g_loss : 1.393188
# batch 2 d_loss : 0.392288
# batch 2 g_loss : 1.128940
# Epoch is 194
# Number of batches 3
# batch 0 d_loss : 0.379512
# batch 0 g_loss : 1.436839
# batch 1 d_loss : 0.567361
# batch 1 g_loss : 1.060909
# batch 2 d_loss : 0.386105
# batch 2 g_loss : 1.269236
# Epoch is 195
# Number of batches 3
# batch 0 d_loss : 0.365975
# batch 0 g_loss : 2.092521
# batch 1 d_loss : 0.526118
# batch 1 g_loss : 1.328981
# batch 2 d_loss : 0.496078
# batch 2 g_loss : 2.159697
# Epoch is 196
# Number of batches 3
# batch 0 d_loss : 0.370850
# batch 0 g_loss : 1.488810
# batch 1 d_loss : 0.456409
# batch 1 g_loss : 0.755443
# batch 2 d_loss : 0.429640
# batch 2 g_loss : 1.492270
# Epoch is 197
# Number of batches 3
# batch 0 d_loss : 0.268450
# batch 0 g_loss : 1.364250
# batch 1 d_loss : 0.545895
# batch 1 g_loss : 1.864256
# batch 2 d_loss : 0.385655
# batch 2 g_loss : 1.571437
# Epoch is 198
# Number of batches 3
# batch 0 d_loss : 0.470812
# batch 0 g_loss : 2.189044
# batch 1 d_loss : 0.539203
# batch 1 g_loss : 1.008107
# batch 2 d_loss : 0.506851
# batch 2 g_loss : 1.679370
# Epoch is 199
# Number of batches 3
# batch 0 d_loss : 0.341588
# batch 0 g_loss : 2.157813
# batch 1 d_loss : 0.506276
# batch 1 g_loss : 0.962525
# batch 2 d_loss : 0.512455
# batch 2 g_loss : 1.949158
# Epoch is 200
# Number of batches 3
# batch 0 d_loss : 0.360068
# batch 0 g_loss : 1.541422
# batch 1 d_loss : 0.564799
# batch 1 g_loss : 1.169078
# batch 2 d_loss : 0.377558
# batch 2 g_loss : 1.689191
# Epoch is 201
# Number of batches 3
# batch 0 d_loss : 0.323306
# batch 0 g_loss : 1.826633
# batch 1 d_loss : 0.571576
# batch 1 g_loss : 1.087880
# batch 2 d_loss : 0.479327
# batch 2 g_loss : 2.022371
# Epoch is 202
# Number of batches 3
# batch 0 d_loss : 0.340378
# batch 0 g_loss : 1.707723
# batch 1 d_loss : 0.500949
# batch 1 g_loss : 1.207924
# batch 2 d_loss : 0.371957
# batch 2 g_loss : 1.298957
# Epoch is 203
# Number of batches 3
# batch 0 d_loss : 0.290534
# batch 0 g_loss : 1.076843
# batch 1 d_loss : 0.485943
# batch 1 g_loss : 1.286987
# batch 2 d_loss : 0.439550
# batch 2 g_loss : 1.528609
# Epoch is 204
# Number of batches 3
# batch 0 d_loss : 0.422379
# batch 0 g_loss : 1.881489
# batch 1 d_loss : 0.553140
# batch 1 g_loss : 1.110926
# batch 2 d_loss : 0.439412
# batch 2 g_loss : 1.522280
# Epoch is 205
# Number of batches 3
# batch 0 d_loss : 0.357926
# batch 0 g_loss : 1.490562
# batch 1 d_loss : 0.609668
# batch 1 g_loss : 1.494648
# batch 2 d_loss : 0.347402
# batch 2 g_loss : 1.281671
# Epoch is 206
# Number of batches 3
# batch 0 d_loss : 0.340817
# batch 0 g_loss : 1.350189
# batch 1 d_loss : 0.506870
# batch 1 g_loss : 1.396377
# batch 2 d_loss : 0.369719
# batch 2 g_loss : 1.493604
# Epoch is 207
# Number of batches 3
# batch 0 d_loss : 0.327902
# batch 0 g_loss : 1.566177
# batch 1 d_loss : 0.444525
# batch 1 g_loss : 1.096709
# batch 2 d_loss : 0.436489
# batch 2 g_loss : 1.458851
# Epoch is 208
# Number of batches 3
# batch 0 d_loss : 0.313461
# batch 0 g_loss : 1.685046
# batch 1 d_loss : 0.476086
# batch 1 g_loss : 1.312356
# batch 2 d_loss : 0.389741
# batch 2 g_loss : 1.489316
# Epoch is 209
# Number of batches 3
# batch 0 d_loss : 0.342697
# batch 0 g_loss : 1.625319
# batch 1 d_loss : 0.531909
# batch 1 g_loss : 1.140866
# batch 2 d_loss : 0.420191
# batch 2 g_loss : 1.384318
# Epoch is 210
# Number of batches 3
# batch 0 d_loss : 0.338208
# batch 0 g_loss : 1.473480
# batch 1 d_loss : 0.558514
# batch 1 g_loss : 1.612343
# batch 2 d_loss : 0.411125
# batch 2 g_loss : 1.374593
# Epoch is 211
# Number of batches 3
# batch 0 d_loss : 0.362841
# batch 0 g_loss : 1.637651
# batch 1 d_loss : 0.467515
# batch 1 g_loss : 0.956620
# batch 2 d_loss : 0.356362
# batch 2 g_loss : 1.165570
# Epoch is 212
# Number of batches 3
# batch 0 d_loss : 0.400315
# batch 0 g_loss : 1.999233
# batch 1 d_loss : 0.522167
# batch 1 g_loss : 1.393641
# batch 2 d_loss : 0.316481
# batch 2 g_loss : 1.072013
# Epoch is 213
# Number of batches 3
# batch 0 d_loss : 0.306970
# batch 0 g_loss : 1.533758
# batch 1 d_loss : 0.424278
# batch 1 g_loss : 1.234040
# batch 2 d_loss : 0.420232
# batch 2 g_loss : 1.458974
# Epoch is 214
# Number of batches 3
# batch 0 d_loss : 0.410848
# batch 0 g_loss : 1.790957
# batch 1 d_loss : 0.493439
# batch 1 g_loss : 1.568903
# batch 2 d_loss : 0.522973
# batch 2 g_loss : 1.643398
# Epoch is 215
# Number of batches 3
# batch 0 d_loss : 0.384408
# batch 0 g_loss : 2.010887
# batch 1 d_loss : 0.475562
# batch 1 g_loss : 1.166888
# batch 2 d_loss : 0.361233
# batch 2 g_loss : 1.237679
# Epoch is 216
# Number of batches 3
# batch 0 d_loss : 0.501221
# batch 0 g_loss : 2.476758
# batch 1 d_loss : 0.567997
# batch 1 g_loss : 1.523500
# batch 2 d_loss : 0.409031
# batch 2 g_loss : 1.676528
# Epoch is 217
# Number of batches 3
# batch 0 d_loss : 0.333416
# batch 0 g_loss : 1.856994
# batch 1 d_loss : 0.484204
# batch 1 g_loss : 0.945509
# batch 2 d_loss : 0.328491
# batch 2 g_loss : 1.228002
# Epoch is 218
# Number of batches 3
# batch 0 d_loss : 0.364836
# batch 0 g_loss : 1.582649
# batch 1 d_loss : 0.475634
# batch 1 g_loss : 1.234948
# batch 2 d_loss : 0.332588
# batch 2 g_loss : 1.448216
# Epoch is 219
# Number of batches 3
# batch 0 d_loss : 0.446843
# batch 0 g_loss : 1.867366
# batch 1 d_loss : 0.475606
# batch 1 g_loss : 1.201051
# batch 2 d_loss : 0.360225
# batch 2 g_loss : 1.221530
# Epoch is 220
# Number of batches 3
# batch 0 d_loss : 0.325780
# batch 0 g_loss : 1.700599
# batch 1 d_loss : 0.470864
# batch 1 g_loss : 1.376143
# batch 2 d_loss : 0.358927
# batch 2 g_loss : 1.223712
# Epoch is 221
# Number of batches 3
# batch 0 d_loss : 0.414572
# batch 0 g_loss : 1.968976
# batch 1 d_loss : 0.493589
# batch 1 g_loss : 1.251304
# batch 2 d_loss : 0.386498
# batch 2 g_loss : 1.362078
# Epoch is 222
# Number of batches 3
# batch 0 d_loss : 0.291413
# batch 0 g_loss : 1.722328
# batch 1 d_loss : 0.412806
# batch 1 g_loss : 1.391414
# batch 2 d_loss : 0.287437
# batch 2 g_loss : 1.251783
# Epoch is 223
# Number of batches 3
# batch 0 d_loss : 0.417674
# batch 0 g_loss : 1.826638
# batch 1 d_loss : 0.445483
# batch 1 g_loss : 1.298175
# batch 2 d_loss : 0.458104
# batch 2 g_loss : 1.467451
# Epoch is 224
# Number of batches 3
# batch 0 d_loss : 0.325335
# batch 0 g_loss : 1.479789
# batch 1 d_loss : 0.416222
# batch 1 g_loss : 1.190436
# batch 2 d_loss : 0.366832
# batch 2 g_loss : 1.238906
# Epoch is 225
# Number of batches 3
# batch 0 d_loss : 0.438711
# batch 0 g_loss : 1.778551
# batch 1 d_loss : 0.536830
# batch 1 g_loss : 1.572672
# batch 2 d_loss : 0.276234
# batch 2 g_loss : 1.130174
# Epoch is 226
# Number of batches 3
# batch 0 d_loss : 0.266971
# batch 0 g_loss : 0.842168
# batch 1 d_loss : 0.350544
# batch 1 g_loss : 1.256574
# batch 2 d_loss : 0.329638
# batch 2 g_loss : 1.656179
# Epoch is 227
# Number of batches 3
# batch 0 d_loss : 0.322988
# batch 0 g_loss : 1.758757
# batch 1 d_loss : 0.467315
# batch 1 g_loss : 1.735454
# batch 2 d_loss : 0.388756
# batch 2 g_loss : 1.373608
# Epoch is 228
# Number of batches 3
# batch 0 d_loss : 0.301744
# batch 0 g_loss : 1.838540
# batch 1 d_loss : 0.379748
# batch 1 g_loss : 1.199950
# batch 2 d_loss : 0.438531
# batch 2 g_loss : 1.060400
# Epoch is 229
# Number of batches 3
# batch 0 d_loss : 0.325219
# batch 0 g_loss : 1.655156
# batch 1 d_loss : 0.457478
# batch 1 g_loss : 1.661518
# batch 2 d_loss : 0.451058
# batch 2 g_loss : 1.571007
# Epoch is 230
# Number of batches 3
# batch 0 d_loss : 0.349984
# batch 0 g_loss : 2.026371
# batch 1 d_loss : 0.480721
# batch 1 g_loss : 1.651007
# batch 2 d_loss : 0.409095
# batch 2 g_loss : 1.490052
# Epoch is 231
# Number of batches 3
# batch 0 d_loss : 0.334185
# batch 0 g_loss : 2.011296
# batch 1 d_loss : 0.466112
# batch 1 g_loss : 1.421151
# batch 2 d_loss : 0.336879
# batch 2 g_loss : 1.398545
# Epoch is 232
# Number of batches 3
# batch 0 d_loss : 0.365985
# batch 0 g_loss : 1.745543
# batch 1 d_loss : 0.555846
# batch 1 g_loss : 2.011340
# batch 2 d_loss : 0.327039
# batch 2 g_loss : 1.319172
# Epoch is 233
# Number of batches 3
# batch 0 d_loss : 0.459494
# batch 0 g_loss : 2.180147
# batch 1 d_loss : 0.448052
# batch 1 g_loss : 1.854067
# batch 2 d_loss : 0.307988
# batch 2 g_loss : 1.349610
# Epoch is 234
# Number of batches 3
# batch 0 d_loss : 0.315522
# batch 0 g_loss : 1.308972
# batch 1 d_loss : 0.415472
# batch 1 g_loss : 1.508730
# batch 2 d_loss : 0.472504
# batch 2 g_loss : 1.543239
# Epoch is 235
# Number of batches 3
# batch 0 d_loss : 0.294661
# batch 0 g_loss : 1.277435
# batch 1 d_loss : 0.419786
# batch 1 g_loss : 1.449360
# batch 2 d_loss : 0.372786
# batch 2 g_loss : 1.460888
# Epoch is 236
# Number of batches 3
# batch 0 d_loss : 0.277120
# batch 0 g_loss : 1.280329
# batch 1 d_loss : 0.353669
# batch 1 g_loss : 1.209945
# batch 2 d_loss : 0.389551
# batch 2 g_loss : 1.578798
# Epoch is 237
# Number of batches 3
# batch 0 d_loss : 0.275267
# batch 0 g_loss : 1.314697
# batch 1 d_loss : 0.445665
# batch 1 g_loss : 1.582280
# batch 2 d_loss : 0.326064
# batch 2 g_loss : 1.510381
# Epoch is 238
# Number of batches 3
# batch 0 d_loss : 0.215266
# batch 0 g_loss : 1.215993
# batch 1 d_loss : 0.502815
# batch 1 g_loss : 2.204252
# batch 2 d_loss : 0.341950
# batch 2 g_loss : 1.639129
# Epoch is 239
# Number of batches 3
# batch 0 d_loss : 0.292417
# batch 0 g_loss : 1.688200
# batch 1 d_loss : 0.406240
# batch 1 g_loss : 1.637985
# batch 2 d_loss : 0.305952
# batch 2 g_loss : 1.465342
# Epoch is 240
# Number of batches 3
# batch 0 d_loss : 0.248872
# batch 0 g_loss : 1.740766
# batch 1 d_loss : 0.391092
# batch 1 g_loss : 1.537275
# batch 2 d_loss : 0.379059
# batch 2 g_loss : 1.725006
# Epoch is 241
# Number of batches 3
# batch 0 d_loss : 0.272148
# batch 0 g_loss : 1.545175
# batch 1 d_loss : 0.428433
# batch 1 g_loss : 1.498381
# batch 2 d_loss : 0.317093
# batch 2 g_loss : 1.709882
# Epoch is 242
# Number of batches 3
# batch 0 d_loss : 0.254674
# batch 0 g_loss : 1.614077
# batch 1 d_loss : 0.360039
# batch 1 g_loss : 1.242524
# batch 2 d_loss : 0.334700
# batch 2 g_loss : 1.500307
# ...
# batch 1 d_loss : 0.239307
# batch 1 g_loss : 2.006905
# batch 2 d_loss : 0.209362
# batch 2 g_loss : 1.813523
# Epoch is 316
# Number of batches 3
# batch 0 d_loss : 0.325314
# batch 0 g_loss : 3.097954
# batch 1 d_loss : 0.312245
# batch 1 g_loss : 2.092841
# batch 2 d_loss : 0.278172
# batch 2 g_loss : 2.472394
# Epoch is 317
# Number of batches 3
# batch 0 d_loss : 0.235855
# batch 0 g_loss : 2.609208
# batch 1 d_loss : 0.272139
# batch 1 g_loss : 1.947611
# batch 2 d_loss : 0.280275
# batch 2 g_loss : 2.122290
# Epoch is 318
# Number of batches 3
# batch 0 d_loss : 0.204133
# batch 0 g_loss : 2.266684
# batch 1 d_loss : 0.266674
# batch 1 g_loss : 2.228650
# batch 2 d_loss : 0.168976
# batch 2 g_loss : 1.723722
# Epoch is 319
# Number of batches 3
# batch 0 d_loss : 0.293754
# batch 0 g_loss : 2.763208
# batch 1 d_loss : 0.283532
# batch 1 g_loss : 2.167591
# batch 2 d_loss : 0.224122
# batch 2 g_loss : 1.871137
# Epoch is 320
# Number of batches 3
# batch 0 d_loss : 0.182973
# batch 0 g_loss : 2.949760
# batch 1 d_loss : 0.364314
# batch 1 g_loss : 3.134227
# batch 2 d_loss : 0.230816
# batch 2 g_loss : 1.267132
# Epoch is 321
# Number of batches 3
# batch 0 d_loss : 0.221468
# batch 0 g_loss : 2.615938
# batch 1 d_loss : 0.276373
# batch 1 g_loss : 2.318267
# batch 2 d_loss : 0.210840
# batch 2 g_loss : 2.481834
# Epoch is 322
# Number of batches 3
# batch 0 d_loss : 0.177288
# batch 0 g_loss : 2.865494
# batch 1 d_loss : 0.245701
# batch 1 g_loss : 2.053847
# batch 2 d_loss : 0.189838
# batch 2 g_loss : 1.986009
# Epoch is 323
# Number of batches 3
# batch 0 d_loss : 0.275957
# batch 0 g_loss : 2.922048
# batch 1 d_loss : 0.304929
# batch 1 g_loss : 2.567754
# batch 2 d_loss : 0.152740
# batch 2 g_loss : 0.972426
# Epoch is 324
# Number of batches 3
# batch 0 d_loss : 0.278827
# batch 0 g_loss : 2.378701
# batch 1 d_loss : 0.264520
# batch 1 g_loss : 1.881308
# batch 2 d_loss : 0.289198
# batch 2 g_loss : 2.483681
# Epoch is 325
# Number of batches 3
# batch 0 d_loss : 0.211792
# batch 0 g_loss : 2.514793
# batch 1 d_loss : 0.312374
# batch 1 g_loss : 2.567933
# batch 2 d_loss : 0.271802
# batch 2 g_loss : 1.941571
# Epoch is 326
# Number of batches 3
# batch 0 d_loss : 0.244925
# batch 0 g_loss : 2.707160
# batch 1 d_loss : 0.353882
# batch 1 g_loss : 2.605570
# batch 2 d_loss : 0.288211
# batch 2 g_loss : 2.411940
# Epoch is 327
# Number of batches 3
# batch 0 d_loss : 0.246188
# batch 0 g_loss : 2.567849
# batch 1 d_loss : 0.274899
# batch 1 g_loss : 2.159382
# batch 2 d_loss : 0.191683
# batch 2 g_loss : 1.474760
# Epoch is 328
# Number of batches 3
# batch 0 d_loss : 0.129351
# batch 0 g_loss : 2.066924
# batch 1 d_loss : 0.261855
# batch 1 g_loss : 1.741810
# batch 2 d_loss : 0.225817
# batch 2 g_loss : 1.987391
# Epoch is 329
# Number of batches 3
# batch 0 d_loss : 0.251233
# batch 0 g_loss : 3.506915
# batch 1 d_loss : 0.361194
# batch 1 g_loss : 2.728664
# batch 2 d_loss : 0.236326
# batch 2 g_loss : 1.702026
# Epoch is 330
# Number of batches 3
# batch 0 d_loss : 0.175017
# batch 0 g_loss : 2.493842
# batch 1 d_loss : 0.206115
# batch 1 g_loss : 1.934797
# batch 2 d_loss : 0.235917
# batch 2 g_loss : 2.272097
# Epoch is 331
# Number of batches 3
# batch 0 d_loss : 0.131765
# batch 0 g_loss : 2.134880
# batch 1 d_loss : 0.239412
# batch 1 g_loss : 1.862737
# batch 2 d_loss : 0.201536
# batch 2 g_loss : 2.331978
# Epoch is 332
# Number of batches 3
# batch 0 d_loss : 0.214598
# batch 0 g_loss : 1.843471
# batch 1 d_loss : 0.265931
# batch 1 g_loss : 2.031931
# batch 2 d_loss : 0.146441
# batch 2 g_loss : 1.562399
# Epoch is 333
# Number of batches 3
# batch 0 d_loss : 0.169428
# batch 0 g_loss : 2.566898
# batch 1 d_loss : 0.301585
# batch 1 g_loss : 2.637651
# batch 2 d_loss : 0.212547
# batch 2 g_loss : 2.486358
# Epoch is 334
# Number of batches 3
# batch 0 d_loss : 0.230366
# batch 0 g_loss : 3.476919
# batch 1 d_loss : 0.318726
# batch 1 g_loss : 1.951634
# batch 2 d_loss : 0.180206
# batch 2 g_loss : 1.955473
# Epoch is 335
# Number of batches 3
# batch 0 d_loss : 0.138876
# batch 0 g_loss : 2.339828
# batch 1 d_loss : 0.190216
# batch 1 g_loss : 2.048414
# batch 2 d_loss : 0.199621
# batch 2 g_loss : 2.327415
# Epoch is 336
# Number of batches 3
# batch 0 d_loss : 0.159104
# batch 0 g_loss : 3.215518
# batch 1 d_loss : 0.269365
# batch 1 g_loss : 2.178121
# batch 2 d_loss : 0.246179
# batch 2 g_loss : 2.003824
# Epoch is 337
# Number of batches 3
# batch 0 d_loss : 0.234834
# batch 0 g_loss : 2.419456
# batch 1 d_loss : 0.251510
# batch 1 g_loss : 2.323583
# batch 2 d_loss : 0.270531
# batch 2 g_loss : 2.589280
# Epoch is 338
# Number of batches 3
# batch 0 d_loss : 0.114691
# batch 0 g_loss : 2.932158
# batch 1 d_loss : 0.247377
# batch 1 g_loss : 2.476645
# batch 2 d_loss : 0.163036
# batch 2 g_loss : 2.728103
# Epoch is 339
# Number of batches 3
# batch 0 d_loss : 0.263511
# batch 0 g_loss : 2.820021
# batch 1 d_loss : 0.298496
# batch 1 g_loss : 2.727863
# batch 2 d_loss : 0.337483
# batch 2 g_loss : 2.992990
# Epoch is 340
# Number of batches 3
# batch 0 d_loss : 0.151556
# batch 0 g_loss : 2.070768
# batch 1 d_loss : 0.315264
# batch 1 g_loss : 2.608400
# batch 2 d_loss : 0.195005
# batch 2 g_loss : 2.282016
# Epoch is 341
# Number of batches 3
# batch 0 d_loss : 0.136117
# batch 0 g_loss : 2.040333
# batch 1 d_loss : 0.251788
# batch 1 g_loss : 2.115042
# batch 2 d_loss : 0.220129
# batch 2 g_loss : 2.639361
# Epoch is 342
# Number of batches 3
# batch 0 d_loss : 0.127319
# batch 0 g_loss : 2.390132
# batch 1 d_loss : 0.247840
# batch 1 g_loss : 1.977505
# batch 2 d_loss : 0.233951
# batch 2 g_loss : 2.465961
# Epoch is 343
# Number of batches 3
# batch 0 d_loss : 0.124061
# batch 0 g_loss : 2.145087
# batch 1 d_loss : 0.260112
# batch 1 g_loss : 2.355014
# batch 2 d_loss : 0.235356
# batch 2 g_loss : 2.308808
# Epoch is 344
# Number of batches 3
# batch 0 d_loss : 0.182802
# batch 0 g_loss : 2.542807
# batch 1 d_loss : 0.224701
# batch 1 g_loss : 1.937765
# batch 2 d_loss : 0.221271
# batch 2 g_loss : 1.710704
# Epoch is 345
# Number of batches 3
# batch 0 d_loss : 0.210275
# batch 0 g_loss : 2.605669
# batch 1 d_loss : 0.225301
# batch 1 g_loss : 2.019660
# batch 2 d_loss : 0.285918
# batch 2 g_loss : 3.085230
# Epoch is 346
# Number of batches 3
# batch 0 d_loss : 0.125162
# batch 0 g_loss : 3.226429
# batch 1 d_loss : 0.269666
# batch 1 g_loss : 1.837969
# batch 2 d_loss : 0.273946
# batch 2 g_loss : 2.986555
# Epoch is 347
# Number of batches 3
# batch 0 d_loss : 0.198802
# batch 0 g_loss : 3.008916
# batch 1 d_loss : 0.250878
# batch 1 g_loss : 2.446863
# batch 2 d_loss : 0.294246
# batch 2 g_loss : 1.570717
# Epoch is 348
# Number of batches 3
# batch 0 d_loss : 0.101474
# batch 0 g_loss : 2.154685
# batch 1 d_loss : 0.208089
# batch 1 g_loss : 2.602575
# batch 2 d_loss : 0.331449
# batch 2 g_loss : 2.874560
# Epoch is 349
# Number of batches 3
# batch 0 d_loss : 0.164362
# batch 0 g_loss : 2.649129
# batch 1 d_loss : 0.257927
# batch 1 g_loss : 1.823733
# batch 2 d_loss : 0.200021
# batch 2 g_loss : 2.115204
# Epoch is 350
# Number of batches 3
# batch 0 d_loss : 0.121898
# batch 0 g_loss : 2.132556
# batch 1 d_loss : 0.200646
# batch 1 g_loss : 2.643826
# batch 2 d_loss : 0.241638
# batch 2 g_loss : 3.064323
# Epoch is 351
# Number of batches 3
# batch 0 d_loss : 0.097735
# batch 0 g_loss : 2.515515
# batch 1 d_loss : 0.177528
# batch 1 g_loss : 2.027015
# batch 2 d_loss : 0.176441
# batch 2 g_loss : 1.180453
# Epoch is 352
# Number of batches 3
# batch 0 d_loss : 0.190165
# batch 0 g_loss : 2.119769
# batch 1 d_loss : 0.248694
# batch 1 g_loss : 2.209675
# batch 2 d_loss : 0.182847
# batch 2 g_loss : 1.757977
# Epoch is 353
# Number of batches 3
# batch 0 d_loss : 0.215328
# batch 0 g_loss : 2.768834
# batch 1 d_loss : 0.212435
# batch 1 g_loss : 2.031164
# batch 2 d_loss : 0.210979
# batch 2 g_loss : 2.457722
# Epoch is 354
# Number of batches 3
# batch 0 d_loss : 0.180827
# batch 0 g_loss : 2.583044
# batch 1 d_loss : 0.248180
# batch 1 g_loss : 2.210656
# batch 2 d_loss : 0.277020
# batch 2 g_loss : 2.349098
# Epoch is 355
# Number of batches 3
# batch 0 d_loss : 0.179192
# batch 0 g_loss : 3.120291
# batch 1 d_loss : 0.264247
# batch 1 g_loss : 2.103163
# batch 2 d_loss : 0.128517
# batch 2 g_loss : 1.446585
# Epoch is 356
# Number of batches 3
# batch 0 d_loss : 0.106957
# batch 0 g_loss : 1.850749
# batch 1 d_loss : 0.222399
# batch 1 g_loss : 1.944249
# batch 2 d_loss : 0.212700
# batch 2 g_loss : 3.101036
# Epoch is 357
# Number of batches 3
# batch 0 d_loss : 0.103003
# batch 0 g_loss : 2.994390
# batch 1 d_loss : 0.215067
# batch 1 g_loss : 2.398739
# batch 2 d_loss : 0.105224
# batch 2 g_loss : 2.094878
# Epoch is 358
# Number of batches 3
# batch 0 d_loss : 0.163229
# batch 0 g_loss : 2.896600
# batch 1 d_loss : 0.219634
# batch 1 g_loss : 2.611686
# batch 2 d_loss : 0.170450
# batch 2 g_loss : 2.517960
# Epoch is 359
# Number of batches 3
# batch 0 d_loss : 0.097987
# batch 0 g_loss : 2.715355
# batch 1 d_loss : 0.264774
# batch 1 g_loss : 2.368201
# batch 2 d_loss : 0.124382
# batch 2 g_loss : 2.498349
# Epoch is 360
# Number of batches 3
# batch 0 d_loss : 0.175381
# batch 0 g_loss : 2.902232
# batch 1 d_loss : 0.270829
# batch 1 g_loss : 2.567796
# batch 2 d_loss : 0.157604
# batch 2 g_loss : 2.200542
# Epoch is 361
# Number of batches 3
# batch 0 d_loss : 0.208887
# batch 0 g_loss : 3.365858
# batch 1 d_loss : 0.274638
# batch 1 g_loss : 2.556198
# batch 2 d_loss : 0.120051
# batch 2 g_loss : 1.749008
# Epoch is 362
# Number of batches 3
# batch 0 d_loss : 0.054898
# batch 0 g_loss : 1.327479
# batch 1 d_loss : 0.244148
# batch 1 g_loss : 2.174644
# batch 2 d_loss : 0.182248
# batch 2 g_loss : 2.684761
# Epoch is 363
# Number of batches 3
# batch 0 d_loss : 0.106720
# batch 0 g_loss : 3.256134
# batch 1 d_loss : 0.244823
# batch 1 g_loss : 2.432671
# batch 2 d_loss : 0.143490
# batch 2 g_loss : 2.605690
# Epoch is 364
# Number of batches 3
# batch 0 d_loss : 0.098575
# batch 0 g_loss : 2.176273
# batch 1 d_loss : 0.240555
# batch 1 g_loss : 2.854135
# batch 2 d_loss : 0.185760
# batch 2 g_loss : 2.214148
# Epoch is 365
# Number of batches 3
# batch 0 d_loss : 0.147896
# batch 0 g_loss : 2.948269
# batch 1 d_loss : 0.223933
# batch 1 g_loss : 2.179627
# batch 2 d_loss : 0.190525
# batch 2 g_loss : 2.266054
# Epoch is 366
# Number of batches 3
# batch 0 d_loss : 0.191306
# batch 0 g_loss : 2.648792
# batch 1 d_loss : 0.273033
# batch 1 g_loss : 2.368227
# batch 2 d_loss : 0.169782
# batch 2 g_loss : 2.677279
# Epoch is 367
# Number of batches 3
# batch 0 d_loss : 0.080734
# batch 0 g_loss : 2.827213
# batch 1 d_loss : 0.207602
# batch 1 g_loss : 2.313192
# batch 2 d_loss : 0.158755
# batch 2 g_loss : 2.081760
# Epoch is 368
# Number of batches 3
# batch 0 d_loss : 0.102597
# batch 0 g_loss : 2.268268
# batch 1 d_loss : 0.219902
# batch 1 g_loss : 2.415295
# batch 2 d_loss : 0.143292
# batch 2 g_loss : 1.846506
# Epoch is 369
# Number of batches 3
# batch 0 d_loss : 0.203816
# batch 0 g_loss : 3.959372
# batch 1 d_loss : 0.268589
# batch 1 g_loss : 2.196886
# batch 2 d_loss : 0.203831
# batch 2 g_loss : 2.258646
# Epoch is 370
# Number of batches 3
# batch 0 d_loss : 0.060015
# batch 0 g_loss : 2.761773
# batch 1 d_loss : 0.208176
# batch 1 g_loss : 2.275031
# batch 2 d_loss : 0.136484
# batch 2 g_loss : 1.917525
# Epoch is 371
# Number of batches 3
# batch 0 d_loss : 0.131329
# batch 0 g_loss : 2.319975
# batch 1 d_loss : 0.232288
# batch 1 g_loss : 1.711232
# batch 2 d_loss : 0.163472
# batch 2 g_loss : 2.704544
# Epoch is 372
# Number of batches 3
# batch 0 d_loss : 0.164395
# batch 0 g_loss : 3.246613
# batch 1 d_loss : 0.244282
# batch 1 g_loss : 2.833889
# batch 2 d_loss : 0.178964
# batch 2 g_loss : 2.743988
# Epoch is 373
# Number of batches 3
# batch 0 d_loss : 0.088129
# batch 0 g_loss : 2.916234
# batch 1 d_loss : 0.212301
# batch 1 g_loss : 2.429964
# batch 2 d_loss : 0.233475
# batch 2 g_loss : 2.676943
# Epoch is 374
# Number of batches 3
# batch 0 d_loss : 0.127239
# batch 0 g_loss : 3.003024
# batch 1 d_loss : 0.272979
# batch 1 g_loss : 1.990233
# batch 2 d_loss : 0.202406
# batch 2 g_loss : 2.257311
# Epoch is 375
# Number of batches 3
# batch 0 d_loss : 0.176072
# batch 0 g_loss : 2.490688
# batch 1 d_loss : 0.228866
# batch 1 g_loss : 2.168592
# batch 2 d_loss : 0.143159
# batch 2 g_loss : 2.305151
# Epoch is 376
# Number of batches 3
# batch 0 d_loss : 0.155456
# batch 0 g_loss : 3.059120
# batch 1 d_loss : 0.252916
# batch 1 g_loss : 2.882011
# batch 2 d_loss : 0.204855
# batch 2 g_loss : 2.729374
# Epoch is 377
# Number of batches 3
# batch 0 d_loss : 0.134095
# batch 0 g_loss : 3.259819
# batch 1 d_loss : 0.251909
# batch 1 g_loss : 2.568963
# batch 2 d_loss : 0.154688
# batch 2 g_loss : 2.586783
# Epoch is 378
# Number of batches 3
# batch 0 d_loss : 0.097507
# batch 0 g_loss : 2.482030
# batch 1 d_loss : 0.191485
# batch 1 g_loss : 1.981129
# batch 2 d_loss : 0.234472
# batch 2 g_loss : 3.074591
# Epoch is 379
# Number of batches 3
# batch 0 d_loss : 0.084806
# batch 0 g_loss : 2.718145
# batch 1 d_loss : 0.251782
# batch 1 g_loss : 2.226871
# batch 2 d_loss : 0.165549
# batch 2 g_loss : 2.410425
# Epoch is 380
# Number of batches 3
# batch 0 d_loss : 0.147061
# batch 0 g_loss : 3.371961
# batch 1 d_loss : 0.259373
# batch 1 g_loss : 2.001822
# batch 2 d_loss : 0.219306
# batch 2 g_loss : 2.979166
# Epoch is 381
# Number of batches 3
# batch 0 d_loss : 0.085518
# batch 0 g_loss : 2.778053
# batch 1 d_loss : 0.239484
# batch 1 g_loss : 2.674172
# batch 2 d_loss : 0.142455
# batch 2 g_loss : 2.566566
# Epoch is 382
# Number of batches 3
# batch 0 d_loss : 0.140425
# batch 0 g_loss : 2.462584
# batch 1 d_loss : 0.202333
# batch 1 g_loss : 2.697404
# batch 2 d_loss : 0.114851
# batch 2 g_loss : 2.541912
# Epoch is 383
# Number of batches 3
# batch 0 d_loss : 0.194009
# batch 0 g_loss : 3.183189
# batch 1 d_loss : 0.232375
# batch 1 g_loss : 1.650891
# batch 2 d_loss : 0.157468
# batch 2 g_loss : 1.909859
# Epoch is 384
# Number of batches 3
# batch 0 d_loss : 0.111368
# batch 0 g_loss : 3.158742
# batch 1 d_loss : 0.184329
# batch 1 g_loss : 2.473433
# batch 2 d_loss : 0.135544
# batch 2 g_loss : 2.192333
# Epoch is 385
# Number of batches 3
# batch 0 d_loss : 0.233805
# batch 0 g_loss : 2.758388
# batch 1 d_loss : 0.242502
# batch 1 g_loss : 2.902999
# batch 2 d_loss : 0.159694
# batch 2 g_loss : 2.779673
# Epoch is 386
# Number of batches 3
# batch 0 d_loss : 0.146630
# batch 0 g_loss : 2.819732
# batch 1 d_loss : 0.196570
# batch 1 g_loss : 2.477731
# batch 2 d_loss : 0.123410
# batch 2 g_loss : 1.933063
# Epoch is 387
# Number of batches 3
# batch 0 d_loss : 0.137488
# batch 0 g_loss : 2.538846
# batch 1 d_loss : 0.211599
# batch 1 g_loss : 2.987189
# batch 2 d_loss : 0.137992
# batch 2 g_loss : 2.554345
# Epoch is 388
# Number of batches 3
# batch 0 d_loss : 0.103744
# batch 0 g_loss : 2.734447
# batch 1 d_loss : 0.189327
# batch 1 g_loss : 2.150200
# batch 2 d_loss : 0.217406
# batch 2 g_loss : 2.745810
# Epoch is 389
# Number of batches 3
# batch 0 d_loss : 0.127412
# batch 0 g_loss : 3.295286
# batch 1 d_loss : 0.274343
# batch 1 g_loss : 2.264938
# batch 2 d_loss : 0.157457
# batch 2 g_loss : 3.258344
# Epoch is 390
# Number of batches 3
# batch 0 d_loss : 0.139012
# batch 0 g_loss : 3.282988
# batch 1 d_loss : 0.211448
# batch 1 g_loss : 1.844811
# batch 2 d_loss : 0.190743
# batch 2 g_loss : 2.861781
# Epoch is 391
# Number of batches 3
# batch 0 d_loss : 0.064446
# batch 0 g_loss : 2.237924
# batch 1 d_loss : 0.173249
# batch 1 g_loss : 2.185283
# batch 2 d_loss : 0.181787
# batch 2 g_loss : 2.633543
# Epoch is 392
# Number of batches 3
# batch 0 d_loss : 0.090165
# batch 0 g_loss : 2.865260
# batch 1 d_loss : 0.193042
# batch 1 g_loss : 2.302639
# batch 2 d_loss : 0.094755
# batch 2 g_loss : 2.309807
# Epoch is 393
# Number of batches 3
# batch 0 d_loss : 0.188639
# batch 0 g_loss : 2.842051
# batch 1 d_loss : 0.314270
# batch 1 g_loss : 3.259953
# batch 2 d_loss : 0.153525
# batch 2 g_loss : 2.576855
# Epoch is 394
# Number of batches 3
# batch 0 d_loss : 0.167841
# batch 0 g_loss : 3.668836
# batch 1 d_loss : 0.241780
# batch 1 g_loss : 2.373883
# batch 2 d_loss : 0.128726
# batch 2 g_loss : 1.979011
# Epoch is 395
# Number of batches 3
# batch 0 d_loss : 0.135228
# batch 0 g_loss : 3.242816
# batch 1 d_loss : 0.192849
# batch 1 g_loss : 2.246711
# batch 2 d_loss : 0.130135
# batch 2 g_loss : 1.977530
# Epoch is 396
# Number of batches 3
# batch 0 d_loss : 0.071400
# batch 0 g_loss : 2.893927
# batch 1 d_loss : 0.149575
# batch 1 g_loss : 2.447811
# batch 2 d_loss : 0.149243
# batch 2 g_loss : 1.640600
# Epoch is 397
# Number of batches 3
# batch 0 d_loss : 0.101555
# batch 0 g_loss : 3.447177
# batch 1 d_loss : 0.186773
# batch 1 g_loss : 2.644706
# batch 2 d_loss : 0.126377
# batch 2 g_loss : 2.357306
# Epoch is 398
# Number of batches 3
# batch 0 d_loss : 0.098270
# batch 0 g_loss : 3.208786
# batch 1 d_loss : 0.148074
# batch 1 g_loss : 2.411988
# batch 2 d_loss : 0.242193
# batch 2 g_loss : 3.603057
# Epoch is 399
# Number of batches 3
# batch 0 d_loss : 0.087161
# batch 0 g_loss : 2.875514
# batch 1 d_loss : 0.205365
# batch 1 g_loss : 2.735319
# batch 2 d_loss : 0.189980
# batch 2 g_loss : 2.467356

# %%
generate(1)
# Out:
# /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=100, units=1024)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (5, 5), padding="same")`
#   del sys.path[0]
# 1/1 [==============================] - 0s 113ms/step
# (1, 1, 128, 128)

# %%
generate(3)
# Out:
# /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=100, units=1024)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# /home/administrator123/anaconda3/envs/Image_Processing/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (5, 5), padding="same")`
#   del sys.path[0]
# 3/3 [==============================] - 0s 50ms/step
# (3, 1, 128, 128)
