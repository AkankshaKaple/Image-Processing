# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image = mpimg.imread('owl-2227574_960_720.jpg')
image_2 = cv.imread('owl-2227574_960_720.jpg')

# %%
plt.imshow(image)
plt.show()

# %%
plt.imshow(image_2)

# %%
# cv.imshow("image", image)
# cv.waitKey(0)
# cv.destroyAllWindows()

# %%
cv.line(image, (0,0), (950,650), (255,0,0), 28)
# Out:
# array([[[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 20,  19,  35],
#         [ 21,  20,  36],
#         [ 22,  21,  37]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 21,  20,  36],
#         [ 22,  21,  37],
#         [ 23,  22,  38]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 22,  21,  37],
#         [ 23,  22,  38],
#         [ 23,  22,  40]],
#
#        ...,
#
#        [[ 22,  20,  33],
#         [ 22,  20,  33],
#         [ 22,  20,  33],
#         ...,
#         [ 21,  21,  33],
#         [ 21,  21,  33],
#         [ 20,  20,  32]],
#
#        [[ 22,  20,  33],
#         [ 22,  20,  33],
#         [ 22,  20,  33],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [ 20,  20,  32]],
#
#        [[ 23,  19,  33],
#         [ 22,  20,  33],
#         [ 22,  20,  33],
# ...

# %%
plt.imshow(image)

# %%
cv.rectangle(image, (100,100), (300,200), (0,0,255), 10)
# Out:
# array([[[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 20,  19,  35],
#         [ 21,  20,  36],
#         [ 22,  21,  37]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 21,  20,  36],
#         [ 22,  21,  37],
#         [ 23,  22,  38]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 22,  21,  37],
#         [ 23,  22,  38],
#         [ 23,  22,  40]],
#
#        ...,
#
#        [[ 22,  20,  33],
#         [ 22,  20,  33],
#         [ 22,  20,  33],
#         ...,
#         [ 21,  21,  33],
#         [ 21,  21,  33],
#         [ 20,  20,  32]],
#
#        [[ 22,  20,  33],
#         [ 22,  20,  33],
#         [ 22,  20,  33],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [ 20,  20,  32]],
#
#        [[ 23,  19,  33],
#         [ 22,  20,  33],
#         [ 22,  20,  33],
# ...

# %%
plt.imshow(image)

# %%
font = cv.FONT_HERSHEY_COMPLEX
cv.putText(image, "Night walker's owl", (50,400), font, 2, (255,255,255), 5, cv.LINE_4)
# Out:
# array([[[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 20,  19,  35],
#         [ 21,  20,  36],
#         [ 22,  21,  37]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 21,  20,  36],
#         [ 22,  21,  37],
#         [ 23,  22,  38]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 22,  21,  37],
#         [ 23,  22,  38],
#         [ 23,  22,  40]],
#
#        ...,
#
#        [[ 22,  20,  33],
#         [ 22,  20,  33],
#         [ 22,  20,  33],
#         ...,
#         [ 21,  21,  33],
#         [ 21,  21,  33],
#         [ 20,  20,  32]],
#
#        [[ 22,  20,  33],
#         [ 22,  20,  33],
#         [ 22,  20,  33],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [ 20,  20,  32]],
#
#        [[ 23,  19,  33],
#         [ 22,  20,  33],
#         [ 22,  20,  33],
# ...

# %%
plt.imshow(image)
